# %% [markdown]
# # Test Loss Functions on Multiple Models

# %%
import sys
sys.path.append('src')
import pandas as pd
import numpy as np
import xgboost as xg
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from utils import create_exp_function, loss_setup, initialize_models
import yaml
import pickle
import os.path as osp
from datetime import timedelta
import matplotlib.pyplot as plt
# Local modules
from data_funcs import train_test_split_spacetime
from fmda_models import LM, XGB, RF
from metrics import ros_0wind, ros_3wind, rmse
import reproducibility

# %% [markdown]
# ## Read Data

# %%
df = pd.read_pickle("data/raws_df.pkl")
df = df.dropna()
df.columns
# Out:
# Index(['Ew', 'Ed', 'temp', 'rh', 'rain', 'precip_accum', 'fm', 'wind', 'solar',
#        'time_raws', 'STID', 'lat', 'lon', 'elev', 'hour', 'doy', 'date'],
#       dtype='object')

# %%
df
# Out:
#                             Ew         Ed     temp    rh  rain  precip_accum  \
# 2023-05-17 03:09:00  13.147834  14.552503  284.817  48.0  0.00       470.408
# 2023-05-17 04:09:00  13.247513  14.652182  284.261  48.0  0.00       470.408
# 2023-05-17 05:09:00  12.876054  14.274707  284.261  46.0  0.00       470.408
# 2023-05-17 06:09:00  13.446692  14.851361  283.150  48.0  0.00       470.408
# 2023-05-17 07:09:00  14.000874  15.412836  283.150  51.0  0.00       470.408
# ...                        ...        ...      ...   ...   ...           ...
# 2024-05-14 19:17:00   5.988904   7.156126  293.706  20.0  0.00         6.096
# 2024-05-14 20:17:00   9.688784  11.031949  290.372  35.0  0.00         6.096
# 2024-05-14 21:17:00  11.794500  13.189754  289.261  45.0  5.08        11.176
# 2024-05-14 22:17:00   7.987530   9.267817  292.039  28.0  0.00        11.176
# 2024-05-14 23:17:00   7.970651   9.239580  290.928  27.0  0.00        11.176
#
#                       fm   wind  solar           time_raws   STID       lat  \
# 2023-05-17 03:09:00  7.5  1.790    1.0 2023-05-17 03:09:00  CPTC2  38.45944
# 2023-05-17 04:09:00  8.1  1.790    0.0 2023-05-17 04:09:00  CPTC2  38.45944
# 2023-05-17 05:09:00  8.6  1.790    0.0 2023-05-17 05:09:00  CPTC2  38.45944
# 2023-05-17 06:09:00  9.2  1.790    0.0 2023-05-17 06:09:00  CPTC2  38.45944
# 2023-05-17 07:09:00  9.6  1.790    0.0 2023-05-17 07:09:00  CPTC2  38.45944
# ...                  ...    ...    ...                 ...    ...       ...
# 2024-05-14 19:17:00  9.4  1.343  970.0 2024-05-14 19:17:00  TT815  37.52272
# 2024-05-14 20:17:00  7.3  0.448  426.0 2024-05-14 20:17:00  TT815  37.52272
# 2024-05-14 21:17:00  8.0  1.343  594.0 2024-05-14 21:17:00  TT815  37.52272
# 2024-05-14 22:17:00  8.0  1.790  742.0 2024-05-14 22:17:00  TT815  37.52272
# 2024-05-14 23:17:00  8.2  0.895  362.0 2024-05-14 23:17:00  TT815  37.52272
#
#                            lon  elev  hour  doy                date
# 2023-05-17 03:09:00 -109.04694  8088     3  137 2023-05-17 03:09:00
# 2023-05-17 04:09:00 -109.04694  8088     4  137 2023-05-17 04:09:00
# 2023-05-17 05:09:00 -109.04694  8088     5  137 2023-05-17 05:09:00
# 2023-05-17 06:09:00 -109.04694  8088     6  137 2023-05-17 06:09:00
# 2023-05-17 07:09:00 -109.04694  8088     7  137 2023-05-17 07:09:00
# ...                        ...   ...   ...  ...                 ...
# 2024-05-14 19:17:00 -108.48178  7576    19  135 2024-05-14 19:17:00
# 2024-05-14 20:17:00 -108.48178  7576    20  135 2024-05-14 20:17:00
# 2024-05-14 21:17:00 -108.48178  7576    21  135 2024-05-14 21:17:00
# 2024-05-14 22:17:00 -108.48178  7576    22  135 2024-05-14 22:17:00
# 2024-05-14 23:17:00 -108.48178  7576    23  135 2024-05-14 23:17:00
#
# [875127 rows x 17 columns]

# %% [markdown]
# ## Setup Models

# %%
with open('models/params.yaml', 'r') as file:
    params = yaml.safe_load(file)

params
# Out:
# {'xgb': {'max_depth': 3,
#   'eta': 0.1,
#   'min_child_weight': 1,
#   'subsample': 0.8,
#   'colsample_bytree': 0.9,
#   'scale_pos_weight': 1,
#   'n_estimators': 100,
#   'gamma': 0.1},
#  'rf': {'n_estimators': 30,
#   'criterion': 'squared_error',
#   'max_depth': 6,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 0.8,
#   'bootstrap': True,
#   'max_samples': None,
#   'random_state': None,
#   'verbose': 0,
#   'warm_start': False},
#  'mlp': {'hidden_units': 10,
#   'activation': 'relu',
#   'optimizer': 'adam',
#   'epochs': 10,
#   'batch_size': 32,
#   'validation_split': 0.2,
#   'dropout': 0.2,
#   'learning_rate': 0.001},
#  'lm': {'fit_intercept': True}}

# %%
weight_grid=np.round(np.linspace(0.01, .25, 10), 4)
models, loss_dict = loss_setup(params=params, ws=weight_grid)
# loss_dict

# %% [markdown]
# ## Run Analysis

# %%
## COLUMNS SUBSET
cols = ["Ed", "rain", "wind", "solar", "hour", "doy", "lat", "lon", 'elev']

# # Get unique month and year combos in the data
# month_year = df.index.to_period('M').unique()
# print(month_year)

reproducibility.set_seed(42)

# my = month_year[1]
# month = my.month
# year = my.year
# print(f"Splitting data for month: {my}")
# df_temp = df[(df.index.month == month) & (df.index.year == year)]
# print(f"Total observations: {df_temp.shape}")
# X_train, X_test, y_train, y_test = train_test_split_spacetime(
#     df_temp, 
#     test_days = 2,
#     spatial_test_frac = 0.2,
#     verbose = True
# )
# X_train = X_train[cols]
# X_test = X_test[cols]
# Out:
# resetting random seeds to 42

# %% [markdown]
# For each loss function and each model, we will collect 2 arrays of errors on the test set. One for the RMSE on the test fuel moisture observations, and another one on the RMSE for the same observations transformed to ROS.

# %%
t = df.index.min()
i = 0
tdelta = 2 # number of days to shift train/test period
while t <= (df.index.max() - timedelta(days = 30)):
    print("~"*50)
    print(f"Iteration: {i}")
    print(f"t: {t}")
    # Build train/test from 30 day period after t
    df_temp = df[
        (df.index >= t) & (df.index < (t + timedelta(days=30)))
    ]
    X_train, X_test, y_train, y_test = train_test_split_spacetime(
        df_temp, 
        test_days = 2,
        spatial_test_frac = 0.2,
        verbose = True
    )
    X_train = X_train[cols]
    X_test = X_test[cols]
    # Run models
    # Reinitialize models dictionary to prevent multiple fitting iterations
    if True:
        models = initialize_models(params)
    for l in loss_dict:
        print("~"*50)
        print(f"Running models for loss func: {l}")
        if loss_dict[l]['w_func'] is not None:
            weights = loss_dict[l]['w_func'](y_train)
        else:
            weights = None

        for mod in models:
            print(f"Fitting {mod}")
            models[mod].fit(X_train, y_train, weights)
            preds = models[mod].predict(X_test)
            loss_dict[l][f"errs"][mod]["t"].append(t)
            loss_dict[l][f"errs"][mod]["rmse_test"].append(rmse(preds, y_test))
            loss_dict[l][f"errs"][mod]["rmse_test_ROS"].append(rmse(ros_3wind(preds), ros_3wind(y_test)))
            print(f"Test RMSE for {mod}: {rmse(preds, y_test)}")
            print(f"Test ROS RMSE for {mod}: {rmse(ros_3wind(preds), ros_3wind(y_test))}")

    # # Iterate test period by 2 so no overlap
    i+= 1 # iteration counter
    t = t + timedelta(days=tdelta)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 0
# t: 2023-05-17 02:22:00
# Number of Training Observations: 52180
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-17 02:22:00', '2023-06-14 02:18:00')
# ----------
# Number of Test Observations: 1052
# Number of Test Locations: 22
# Time range Test: ('2023-06-14 02:20:00', '2023-06-16 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8045966964934887
# Test ROS RMSE for XGB: 0.006062022330028254
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.182792561172982
# Test ROS RMSE for LM: 0.0069023249236351775
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.790257572068128
# Test ROS RMSE for RF: 0.006034513723919833
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.752062524947837
# Test ROS RMSE for XGB: 0.006014988945458873
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.166002332431029
# Test ROS RMSE for LM: 0.0068400846125014425
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.788942539426092
# Test ROS RMSE for RF: 0.006063400928912017
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.820447519805008
# Test ROS RMSE for XGB: 0.00610982764675172
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.1550814307223884
# Test ROS RMSE for LM: 0.006733185121670884
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.813126856225234
# Test ROS RMSE for RF: 0.006085846173238951
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.796847257964448
# Test ROS RMSE for XGB: 0.006080956633978842
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.195112525019072
# Test ROS RMSE for LM: 0.006722525449775049
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.8945649747916216
# Test ROS RMSE for RF: 0.006216684535546139
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8435080169288276
# Test ROS RMSE for XGB: 0.00614167722266354
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.287666551283418
# Test ROS RMSE for LM: 0.006805504088391422
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.023941882346927
# Test ROS RMSE for RF: 0.006376101370961201
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9697723751925356
# Test ROS RMSE for XGB: 0.006300779786066111
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.429973060461246
# Test ROS RMSE for LM: 0.006969296201373649
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.1776417479474075
# Test ROS RMSE for RF: 0.0065691425200156296
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.101074091739634
# Test ROS RMSE for XGB: 0.006484073624462483
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.613253899291186
# Test ROS RMSE for LM: 0.007190508626006392
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.426955429767681
# Test ROS RMSE for RF: 0.00689528291649236
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.295803246914596
# Test ROS RMSE for XGB: 0.006721948399058564
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.8267640271601655
# Test ROS RMSE for LM: 0.0074473967836082774
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.614615718020009
# Test ROS RMSE for RF: 0.007135441340958591
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.436439796117331
# Test ROS RMSE for XGB: 0.006896072196013824
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.056314051361953
# Test ROS RMSE for LM: 0.007718660855203001
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.842165449122903
# Test ROS RMSE for RF: 0.00741287443312896
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.6190888380131065
# Test ROS RMSE for XGB: 0.007137643410262621
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.288771582513835
# Test ROS RMSE for LM: 0.007991704342687776
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.090374550229682
# Test ROS RMSE for RF: 0.007722895877845159
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.887394492479457
# Test ROS RMSE for XGB: 0.007466275296106968
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.516604048205675
# Test ROS RMSE for LM: 0.00825998876537297
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.234404547196259
# Test ROS RMSE for RF: 0.007883408291823062
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7854543845670596
# Test ROS RMSE for XGB: 0.006083651021983684
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.1692618449678625
# Test ROS RMSE for LM: 0.006721744003530483
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7974134407035613
# Test ROS RMSE for RF: 0.006130569620582753
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 1
# t: 2023-05-19 02:22:00
# Number of Training Observations: 53692
# Number of Training Locations: 85
# Number of Features: 16
# Time range Train: ('2023-05-19 02:22:00', '2023-06-16 02:18:00')
# ----------
# Number of Test Observations: 960
# Number of Test Locations: 20
# Time range Test: ('2023-06-16 02:23:00', '2023-06-18 02:16:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8069644402484983
# Test ROS RMSE for XGB: 0.006330804037970208
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.195258042444763
# Test ROS RMSE for LM: 0.006992053111675874
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.8477878076176246
# Test ROS RMSE for RF: 0.0062739783591109705
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.81978007371632
# Test ROS RMSE for XGB: 0.006374439438625053
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.2080415582031065
# Test ROS RMSE for LM: 0.006970399096218844
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.864898245441629
# Test ROS RMSE for RF: 0.006302229249458749
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.936306230099118
# Test ROS RMSE for XGB: 0.006533921495942999
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.275812073563366
# Test ROS RMSE for LM: 0.006974689920818295
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.9532966557535807
# Test ROS RMSE for RF: 0.006457376366309968
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.067178118176652
# Test ROS RMSE for XGB: 0.006696826748197876
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.393260579167001
# Test ROS RMSE for LM: 0.007077885737621403
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.066547085209062
# Test ROS RMSE for RF: 0.006604422572522903
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.159048699265888
# Test ROS RMSE for XGB: 0.006830459141396071
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.561960929273332
# Test ROS RMSE for LM: 0.00727573367294031
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.222328620926368
# Test ROS RMSE for RF: 0.006827170050119746
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.323484030268185
# Test ROS RMSE for XGB: 0.007038457507639319
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.778340480221079
# Test ROS RMSE for LM: 0.00755096732248128
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.39772682112755
# Test ROS RMSE for RF: 0.007045853303945801
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.494487924200962
# Test ROS RMSE for XGB: 0.007251385334955208
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.032774412675683
# Test ROS RMSE for LM: 0.00787534339101565
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.604699048656874
# Test ROS RMSE for RF: 0.007323497016353986
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.747092758223221
# Test ROS RMSE for XGB: 0.0075555395037335705
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.314298306095921
# Test ROS RMSE for LM: 0.008224077167422817
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.8051088311203
# Test ROS RMSE for RF: 0.007571674471054173
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.923286541360585
# Test ROS RMSE for XGB: 0.007792890055903296
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.607562933756487
# Test ROS RMSE for LM: 0.008574888231286371
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.065750949950957
# Test ROS RMSE for RF: 0.007879425088204727
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.164173632492083
# Test ROS RMSE for XGB: 0.008056464900110175
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.898389936344572
# Test ROS RMSE for LM: 0.008913644230528041
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.343234839098545
# Test ROS RMSE for RF: 0.008220500015892121
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.441279269060806
# Test ROS RMSE for XGB: 0.00839018351403409
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.179109999648606
# Test ROS RMSE for LM: 0.009236810085788947
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.621693290634355
# Test ROS RMSE for RF: 0.00854052066575703
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9487343392936705
# Test ROS RMSE for XGB: 0.0065694535260649575
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.332605343741416
# Test ROS RMSE for LM: 0.007021400743444201
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.990339028230818
# Test ROS RMSE for RF: 0.0065376870066970105
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 2
# t: 2023-05-21 02:22:00
# Number of Training Observations: 53707
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-21 02:22:00', '2023-06-18 02:18:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-18 02:23:00', '2023-06-20 02:14:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7874975391910493
# Test ROS RMSE for XGB: 0.005280044910409524
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9302243354890827
# Test ROS RMSE for LM: 0.005421890757944527
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4369084859618373
# Test ROS RMSE for RF: 0.004344041317573018
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.680168624809509
# Test ROS RMSE for XGB: 0.005058992256672598
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.8785764978063946
# Test ROS RMSE for LM: 0.005336711891092834
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.392719542695057
# Test ROS RMSE for RF: 0.004253736908554203
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.613372521098137
# Test ROS RMSE for XGB: 0.005048756736916137
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.786822592366913
# Test ROS RMSE for LM: 0.0051822979425766415
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4218133371997346
# Test ROS RMSE for RF: 0.004268774307657534
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.519323999389203
# Test ROS RMSE for XGB: 0.004820628472038821
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7522810245208422
# Test ROS RMSE for LM: 0.005097966578946514
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.395450538481583
# Test ROS RMSE for RF: 0.004183573133345557
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.435375586447776
# Test ROS RMSE for XGB: 0.004617926402554373
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7655042136062895
# Test ROS RMSE for LM: 0.0050547178957035645
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4257763184371814
# Test ROS RMSE for RF: 0.004169756960144661
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.3657074703050864
# Test ROS RMSE for XGB: 0.004379320140302241
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.819325446970724
# Test ROS RMSE for LM: 0.005043183649243274
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4949222634417407
# Test ROS RMSE for RF: 0.004263834036862041
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.469802515723205
# Test ROS RMSE for XGB: 0.004518782725272407
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9055473026968146
# Test ROS RMSE for LM: 0.005060793510755372
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.5687365858127302
# Test ROS RMSE for RF: 0.004309983600013072
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.492771806816543
# Test ROS RMSE for XGB: 0.004432685094040751
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.015874739021584
# Test ROS RMSE for LM: 0.005109728772032911
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.6501179969931155
# Test ROS RMSE for RF: 0.004374767410435954
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5703952329947373
# Test ROS RMSE for XGB: 0.004506997908647935
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1407116314624313
# Test ROS RMSE for LM: 0.005187000771015467
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.81249567761654
# Test ROS RMSE for RF: 0.00453099391039841
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7089020428290613
# Test ROS RMSE for XGB: 0.004630698568457547
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.271206794360609
# Test ROS RMSE for LM: 0.0052864219417203435
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.9293823168261754
# Test ROS RMSE for RF: 0.00467129543512133
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.8102739969108215
# Test ROS RMSE for XGB: 0.0046609311105559265
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.4019184276041785
# Test ROS RMSE for LM: 0.005401896304082013
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.047983216696292
# Test ROS RMSE for RF: 0.0047429082538224246
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5390878538835193
# Test ROS RMSE for XGB: 0.004922921043172577
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7563728854564133
# Test ROS RMSE for LM: 0.00508599242222978
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.374299164271186
# Test ROS RMSE for RF: 0.0041939108260169436
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 3
# t: 2023-05-23 02:22:00
# Number of Training Observations: 53653
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-23 02:22:00', '2023-06-20 02:18:00')
# ----------
# Number of Test Observations: 1056
# Number of Test Locations: 22
# Time range Test: ('2023-06-20 02:20:00', '2023-06-22 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.927267485999719
# Test ROS RMSE for XGB: 0.005995518460646232
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.3973255780153226
# Test ROS RMSE for LM: 0.006925896664336967
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.0247561918235233
# Test ROS RMSE for RF: 0.006384626014985516
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.9331947459498355
# Test ROS RMSE for XGB: 0.005972658292448037
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.347173453331452
# Test ROS RMSE for LM: 0.006842150045283945
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.987722016174811
# Test ROS RMSE for RF: 0.006382767662157254
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.801234328737196
# Test ROS RMSE for XGB: 0.005832989323445676
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.2356267837828363
# Test ROS RMSE for LM: 0.006671884972051236
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8878924927788825
# Test ROS RMSE for RF: 0.00630423927768283
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7770267627985166
# Test ROS RMSE for XGB: 0.005812599146293289
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1517816439517485
# Test ROS RMSE for LM: 0.0065461920695148975
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8310338922847977
# Test ROS RMSE for RF: 0.0061935789524881065
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.703793556988454
# Test ROS RMSE for XGB: 0.005649857610085423
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.094007038750565
# Test ROS RMSE for LM: 0.006447438588533634
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7970774856084617
# Test ROS RMSE for RF: 0.006114744425821808
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.670559157798733
# Test ROS RMSE for XGB: 0.005595740197854014
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0645758998317807
# Test ROS RMSE for LM: 0.006373206207874499
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.77256019884076
# Test ROS RMSE for RF: 0.006121780099014557
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6633685120821373
# Test ROS RMSE for XGB: 0.005548933793669073
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.064550871707777
# Test ROS RMSE for LM: 0.0063241025291783225
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7658304334430905
# Test ROS RMSE for RF: 0.006028761655429982
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6992767058221583
# Test ROS RMSE for XGB: 0.005561890551558558
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.092140295834156
# Test ROS RMSE for LM: 0.006303848633155429
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7790143589751044
# Test ROS RMSE for RF: 0.005989219217717088
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.748618700032444
# Test ROS RMSE for XGB: 0.005605115737230487
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1426191463712314
# Test ROS RMSE for LM: 0.00630823888526481
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.828410896293178
# Test ROS RMSE for RF: 0.00592848426412847
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7665405332894983
# Test ROS RMSE for XGB: 0.005609268937392297
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.209298243127318
# Test ROS RMSE for LM: 0.006332993484893564
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.897422030025976
# Test ROS RMSE for RF: 0.006041214581747497
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.8489554037424822
# Test ROS RMSE for XGB: 0.005701409495741388
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.286283331932443
# Test ROS RMSE for LM: 0.006373866164990179
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.961897802421593
# Test ROS RMSE for RF: 0.0060792729691324775
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.791539056847142
# Test ROS RMSE for XGB: 0.005792677283618202
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1837512067661957
# Test ROS RMSE for LM: 0.006577031009070547
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.859399821744596
# Test ROS RMSE for RF: 0.006164334719285588
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 4
# t: 2023-05-25 02:22:00
# Number of Training Observations: 53995
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-25 02:22:00', '2023-06-22 02:16:00')
# ----------
# Number of Test Observations: 1003
# Number of Test Locations: 21
# Time range Test: ('2023-06-22 02:20:00', '2023-06-24 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.773712608928576
# Test ROS RMSE for XGB: 0.007303431770832704
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.025828543501411
# Test ROS RMSE for LM: 0.007929413199907347
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6264438751602333
# Test ROS RMSE for RF: 0.0069642512512059765
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8924838060785136
# Test ROS RMSE for XGB: 0.007375435530373477
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.020073816875051
# Test ROS RMSE for LM: 0.007903572161266467
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6120712378488276
# Test ROS RMSE for RF: 0.007009510921474472
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9814520782937137
# Test ROS RMSE for XGB: 0.007468748752891882
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.0345374728684105
# Test ROS RMSE for LM: 0.007874158292881805
# Fitting RF
# ...
# Predicting with RF
# Test RMSE for RF: 5.876355288540104
# Test ROS RMSE for RF: 0.009028169591312332
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.692954284171568
# Test ROS RMSE for XGB: 0.008714638810264146
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.036687408805466
# Test ROS RMSE for LM: 0.009409613395445767
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.148984560865471
# Test ROS RMSE for RF: 0.009371434079632134
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.1753959158440965
# Test ROS RMSE for XGB: 0.009217088359059858
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.343291471067049
# Test ROS RMSE for LM: 0.009690655698452802
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.383415527566147
# Test ROS RMSE for RF: 0.009667170806075015
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.31283216854126
# Test ROS RMSE for XGB: 0.009410415637198856
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.619774496303886
# Test ROS RMSE for LM: 0.00996478194759005
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.63415983074483
# Test ROS RMSE for RF: 0.009958957295025548
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.781355436964353
# Test ROS RMSE for XGB: 0.009979464665054673
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.8679081641322295
# Test ROS RMSE for LM: 0.01023535209631841
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.833064400568196
# Test ROS RMSE for RF: 0.010215874057432569
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.579107382935354
# Test ROS RMSE for XGB: 0.007461751891063289
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.6656082682598115
# Test ROS RMSE for LM: 0.008302560890589786
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.754616665142601
# Test ROS RMSE for RF: 0.007821573347469218
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 166
# t: 2024-04-13 02:22:00
# Number of Training Observations: 56083
# Number of Training Locations: 88
# Number of Features: 16
# Time range Train: ('2024-04-13 02:22:00', '2024-05-11 02:17:00')
# ----------
# Number of Test Observations: 1002
# Number of Test Locations: 21
# Time range Test: ('2024-05-11 02:20:00', '2024-05-13 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.148995039278544
# Test ROS RMSE for XGB: 0.006569105719164935
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.077280384026249
# Test ROS RMSE for LM: 0.0064690974255136105
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.4856170661280625
# Test ROS RMSE for RF: 0.006935703040298585
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.2768129567143305
# Test ROS RMSE for XGB: 0.006740246907871838
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.147295332038821
# Test ROS RMSE for LM: 0.006562768374878104
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.550751303052251
# Test ROS RMSE for RF: 0.007014152236334083
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.507752984076796
# Test ROS RMSE for XGB: 0.006973063920810439
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.393132942082354
# Test ROS RMSE for LM: 0.006886655208792597
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.84020918272063
# Test ROS RMSE for RF: 0.0074192286868070435
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.837916815861014
# Test ROS RMSE for XGB: 0.0073834124690187845
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.708087480147421
# Test ROS RMSE for LM: 0.007270121395121378
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.986174383062235
# Test ROS RMSE for RF: 0.007580152558117813
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.0136061911445395
# Test ROS RMSE for XGB: 0.007607394992016594
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.067867204253711
# Test ROS RMSE for LM: 0.00768167075637655
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.371446179829663
# Test ROS RMSE for RF: 0.008023060823623302
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.225609150276799
# Test ROS RMSE for XGB: 0.007808572291974
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.4428479527093385
# Test ROS RMSE for LM: 0.00809713078388197
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.644074299983801
# Test ROS RMSE for RF: 0.008311044782254843
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.2813269550707895
# Test ROS RMSE for XGB: 0.007817252667161401
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.808161517081461
# Test ROS RMSE for LM: 0.008506742680375122
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.004418304090686
# Test ROS RMSE for RF: 0.008770268490391302
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.6295664856934815
# Test ROS RMSE for XGB: 0.008218620400578821
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.151143723494074
# Test ROS RMSE for LM: 0.008907767431475975
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.573223199662721
# Test ROS RMSE for RF: 0.009505721460385193
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.973288589682803
# Test ROS RMSE for XGB: 0.008733751468252688
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.462691028906342
# Test ROS RMSE for LM: 0.009295532832172746
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.8418133061112565
# Test ROS RMSE for RF: 0.00993334732280615
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.235522022731369
# Test ROS RMSE for XGB: 0.009081910730531035
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.739909767450289
# Test ROS RMSE for LM: 0.009666293719419817
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.041778804560676
# Test ROS RMSE for RF: 0.010184610575115733
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.709897351390177
# Test ROS RMSE for XGB: 0.009659034549405445
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.98651690224943
# Test ROS RMSE for LM: 0.010021837897773016
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.260065199683412
# Test ROS RMSE for RF: 0.010544005304759576
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.462290613487074
# Test ROS RMSE for XGB: 0.006874289997602103
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.597333906653924
# Test ROS RMSE for LM: 0.007167079887638475
# Fitting RF
# Training RF with params: {'n_estimators': 30, 'criterion': 'squared_error', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.811028632049745
# Test ROS RMSE for RF: 0.0073463249055358455

# %%
results_fm = []
results_ros = []
for l in loss_dict:
    for mod in loss_dict[l]["errs"]:
        errs = loss_dict[l]["errs"][mod]['rmse_test']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_fm.append(pd.DataFrame(temp))
        errs = loss_dict[l]["errs"][mod]['rmse_test_ROS']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test_ROS'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_ros.append(pd.DataFrame(temp))

# %%
results_fm = pd.concat(results_fm)
results_fm
# Out:
#          RMSE Loss Model                   t
# 0    3.804597  MSE   XGB 2023-05-17 02:22:00
# 1    3.806964  MSE   XGB 2023-05-19 02:22:00
# 2    2.787498  MSE   XGB 2023-05-21 02:22:00
# 3    2.927267  MSE   XGB 2023-05-23 02:22:00
# 4    3.773713  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  4.199529  ROS    RF 2024-04-05 02:22:00
# 163  2.936546  ROS    RF 2024-04-07 02:22:00
# 164  4.715967  ROS    RF 2024-04-09 02:22:00
# 165  4.754617  ROS    RF 2024-04-11 02:22:00
# 166  4.811029  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
results_ros = pd.concat(results_ros)
results_ros
# Out:
#          RMSE Loss Model                   t
# 0    0.006062  MSE   XGB 2023-05-17 02:22:00
# 1    0.006331  MSE   XGB 2023-05-19 02:22:00
# 2    0.005280  MSE   XGB 2023-05-21 02:22:00
# 3    0.005996  MSE   XGB 2023-05-23 02:22:00
# 4    0.007303  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  0.006957  ROS    RF 2024-04-05 02:22:00
# 163  0.004891  ROS    RF 2024-04-07 02:22:00
# 164  0.008322  ROS    RF 2024-04-09 02:22:00
# 165  0.007822  ROS    RF 2024-04-11 02:22:00
# 166  0.007346  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
# Write Dataframe
with open(osp.join("outputs", "results_fm.pkl"), 'wb') as handle:
    pickle.dump(results_fm, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(osp.join("outputs", "results_ros.pkl"), 'wb') as handle:
    pickle.dump(results_ros, handle, protocol=pickle.HIGHEST_PROTOCOL)
