# %% [markdown]
# # Test Loss Functions on Multiple Models

# %%
import sys
sys.path.append('src')
import pandas as pd
import numpy as np
import xgboost as xg
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import yaml
import pickle
import os.path as osp
from datetime import timedelta
import matplotlib.pyplot as plt
# Local modules
from data_funcs import train_test_split_spacetime
from fmda_models import LM, XGB, RF
from metrics import ros, rmse
import reproducibility

# %% [markdown]
# ## Read Data

# %%
df = pd.read_pickle("data/raws_df.pkl")
df = df.dropna()
df.columns
# Out:
# Index(['Ew', 'Ed', 'temp', 'rh', 'rain', 'precip_accum', 'fm', 'wind', 'solar',
#        'time_raws', 'STID', 'lat', 'lon', 'elev', 'hour', 'doy', 'date'],
#       dtype='object')

# %%
df
# Out:
#                             Ew         Ed     temp    rh  rain  precip_accum  \
# 2023-05-17 03:09:00  13.147834  14.552503  284.817  48.0  0.00       470.408
# 2023-05-17 04:09:00  13.247513  14.652182  284.261  48.0  0.00       470.408
# 2023-05-17 05:09:00  12.876054  14.274707  284.261  46.0  0.00       470.408
# 2023-05-17 06:09:00  13.446692  14.851361  283.150  48.0  0.00       470.408
# 2023-05-17 07:09:00  14.000874  15.412836  283.150  51.0  0.00       470.408
# ...                        ...        ...      ...   ...   ...           ...
# 2024-05-14 19:17:00   5.988904   7.156126  293.706  20.0  0.00         6.096
# 2024-05-14 20:17:00   9.688784  11.031949  290.372  35.0  0.00         6.096
# 2024-05-14 21:17:00  11.794500  13.189754  289.261  45.0  5.08        11.176
# 2024-05-14 22:17:00   7.987530   9.267817  292.039  28.0  0.00        11.176
# 2024-05-14 23:17:00   7.970651   9.239580  290.928  27.0  0.00        11.176
#
#                       fm   wind  solar           time_raws   STID       lat  \
# 2023-05-17 03:09:00  7.5  1.790    1.0 2023-05-17 03:09:00  CPTC2  38.45944
# 2023-05-17 04:09:00  8.1  1.790    0.0 2023-05-17 04:09:00  CPTC2  38.45944
# 2023-05-17 05:09:00  8.6  1.790    0.0 2023-05-17 05:09:00  CPTC2  38.45944
# 2023-05-17 06:09:00  9.2  1.790    0.0 2023-05-17 06:09:00  CPTC2  38.45944
# 2023-05-17 07:09:00  9.6  1.790    0.0 2023-05-17 07:09:00  CPTC2  38.45944
# ...                  ...    ...    ...                 ...    ...       ...
# 2024-05-14 19:17:00  9.4  1.343  970.0 2024-05-14 19:17:00  TT815  37.52272
# 2024-05-14 20:17:00  7.3  0.448  426.0 2024-05-14 20:17:00  TT815  37.52272
# 2024-05-14 21:17:00  8.0  1.343  594.0 2024-05-14 21:17:00  TT815  37.52272
# 2024-05-14 22:17:00  8.0  1.790  742.0 2024-05-14 22:17:00  TT815  37.52272
# 2024-05-14 23:17:00  8.2  0.895  362.0 2024-05-14 23:17:00  TT815  37.52272
#
#                            lon  elev  hour  doy                date
# 2023-05-17 03:09:00 -109.04694  8088     3  137 2023-05-17 03:09:00
# 2023-05-17 04:09:00 -109.04694  8088     4  137 2023-05-17 04:09:00
# 2023-05-17 05:09:00 -109.04694  8088     5  137 2023-05-17 05:09:00
# 2023-05-17 06:09:00 -109.04694  8088     6  137 2023-05-17 06:09:00
# 2023-05-17 07:09:00 -109.04694  8088     7  137 2023-05-17 07:09:00
# ...                        ...   ...   ...  ...                 ...
# 2024-05-14 19:17:00 -108.48178  7576    19  135 2024-05-14 19:17:00
# 2024-05-14 20:17:00 -108.48178  7576    20  135 2024-05-14 20:17:00
# 2024-05-14 21:17:00 -108.48178  7576    21  135 2024-05-14 21:17:00
# 2024-05-14 22:17:00 -108.48178  7576    22  135 2024-05-14 22:17:00
# 2024-05-14 23:17:00 -108.48178  7576    23  135 2024-05-14 23:17:00
#
# [875127 rows x 17 columns]

# %% [markdown]
# ## Setup Models

# %%
with open('models/params.yaml', 'r') as file:
    params = yaml.safe_load(file)

params
# Out:
# {'xgb': {'max_depth': 3,
#   'eta': 0.1,
#   'min_child_weight': 1,
#   'subsample': 0.8,
#   'colsample_bytree': 0.9,
#   'scale_pos_weight': 1,
#   'n_estimators': 100,
#   'gamma': 0.1},
#  'rf': {'n_estimators': 25,
#   'criterion': 'squared_error',
#   'max_depth': 5,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 0.8,
#   'bootstrap': True,
#   'max_samples': None,
#   'random_state': None,
#   'verbose': 0,
#   'warm_start': False},
#  'mlp': {'hidden_units': 10,
#   'activation': 'relu',
#   'optimizer': 'adam',
#   'epochs': 10,
#   'batch_size': 32,
#   'validation_split': 0.2,
#   'dropout': 0.2,
#   'learning_rate': 0.001},
#  'lm': {'fit_intercept': True}}

# %%
def initialize_models():
    models = {
        'XGB' : XGB(params['xgb']),
        'LM' : LM(params['lm']),
        'RF' : RF(params['rf'])
    }

    return models

models = initialize_models()

# %%
def create_exp_function(w):
    def exp_function(y_train):
        return tf.exp(tf.multiply(-w, y_train))
    return exp_function

## Function test:
# fun = create_exp_function(.05)
# fun(y_train = np.array([1,2,3]))

# %%
def loss_setup(ws = None):
    loss_fucs = ["MSE", "exp", "ROS"]
    # set up return dictionary
    loss = {
        'MSE' : {
            'w_func' : None
        }
    } 
    # Using input omega parameter list, add dictionary key for exponential weighting for each omega in list 
    if ws is not None:
        for w in ws:
            assert isinstance(w, float) # Check that given list of floats
            dname = f"exp_{w}" # create name of dictionary key
            loss[dname] = {
                'w_func' : create_exp_function(w)
            }
    loss["ROS"] = {'w_func': ros}
    return loss

# %%
weight_grid=np.round(np.linspace(0.01, .25, 10), 4)
print(f"Grid of Omega Weights: {weight_grid}")
loss_dict = loss_setup(ws=weight_grid)
loss_dict
# Out:
# Grid of Omega Weights: [0.01   0.0367 0.0633 0.09   0.1167 0.1433 0.17   0.1967 0.2233 0.25  ]
# {'MSE': {'w_func': None},
#  'exp_0.01': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.0367': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.0633': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.09': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.1167': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.1433': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.17': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.1967': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.2233': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'exp_0.25': {'w_func': <function __main__.create_exp_function.<locals>.exp_function(y_train)>},
#  'ROS': {'w_func': <function metrics.ros(fm)>}}

# %% [markdown]
# ## Run Analysis

# %%
## COLUMNS SUBSET
cols = ["Ed", "rain", "wind", "solar", "hour", "doy", "lat", "lon", 'elev']

# Get unique month and year combos in the data
month_year = df.index.to_period('M').unique()
print(month_year)

reproducibility.set_seed(42)


my = month_year[1]
month = my.month
year = my.year
print(f"Splitting data for month: {my}")
df_temp = df[(df.index.month == month) & (df.index.year == year)]
print(f"Total observations: {df_temp.shape}")
X_train, X_test, y_train, y_test = train_test_split_spacetime(
    df_temp, 
    test_days = 2,
    spatial_test_frac = 0.2,
    verbose = True
)
X_train = X_train[cols]
X_test = X_test[cols]
# Out:
# PeriodIndex(['2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10',
#              '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04',
#              '2024-05'],
#             dtype='period[M]')
# resetting random seeds to 42
# Splitting data for month: 2023-06
# Total observations: (73003, 17)
# Number of Training Observations: 53896
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-06-01 00:03:00', '2023-06-28 23:58:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-29 00:06:00', '2023-06-30 23:55:00')

# %% [markdown]
# For each loss function and each model, we will collect 2 arrays of errors on the test set. One for the RMSE on the test fuel moisture observations, and another one on the RMSE for the same observations transformed to ROS.

# %%
for l in loss_dict:
    loss_dict[l][f"errs"]={}
    for mod in models:
        loss_dict[l][f"errs"][mod] = {
            "rmse_test" : [],
            "rmse_test_ROS" : [],
            "t": [] # time of earliest train period
        }

# %%
# Get unique month and year combos in the data
month_year = df.index.to_period('M').unique()
my = month_year.min()
t = df.index.min()
i = 0
tdelta = 2 # number of days to shift train/test period
while t <= (df.index.max() - timedelta(days = 30)):
    print("~"*50)
    print(f"Iteration: {i}")
    print(f"t: {t}")
    # Build train/test from 30 day period after t
    df_temp = df[
        (df.index >= t) & (df.index < (t + timedelta(days=30)))
    ]
    X_train, X_test, y_train, y_test = train_test_split_spacetime(
        df_temp, 
        test_days = 2,
        spatial_test_frac = 0.2,
        verbose = True
    )
    X_train = X_train[cols]
    X_test = X_test[cols]
    # Run models
    for l in loss_dict:
        print("~"*50)
        print(f"Running models for loss func: {l}")
        if loss_dict[l]['w_func'] is not None:
            weights = loss_dict[l]['w_func'](y_train)
        else:
            weights = None
        # Reinitialize models dictionary to prevent multiple fitting iterations
        # if True:
        #     models = initialize_models()
        for mod in models:
            print(f"Fitting {mod}")
            models[mod].fit(X_train, y_train, weights)
            preds = models[mod].predict(X_test)
            loss_dict[l][f"errs"][mod]["t"].append(t)
            loss_dict[l][f"errs"][mod]["rmse_test"].append(rmse(preds, y_test))
            loss_dict[l][f"errs"][mod]["rmse_test_ROS"].append(rmse(ros(preds), ros(y_test)))
            print(f"Test RMSE for {mod}: {rmse(preds, y_test)}")
            print(f"Test ROS RMSE for {mod}: {rmse(ros(preds), ros(y_test))}")

    # # Iterate test period by 2 so no overlap
    i+= 1 # iteration counter
    t = t + timedelta(days=tdelta)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 0
# t: 2023-05-17 02:22:00
# Number of Training Observations: 53119
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-17 02:22:00', '2023-06-14 02:18:00')
# ----------
# Number of Test Observations: 1056
# Number of Test Locations: 22
# Time range Test: ('2023-06-14 02:22:00', '2023-06-16 02:16:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.23343017769808
# Test ROS RMSE for XGB: 0.0003989533946006983
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.5172081935106685
# Test ROS RMSE for LM: 0.0004498712567688833
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.2679624459910688
# Test ROS RMSE for RF: 0.00040605445828906754
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.2818815701641597
# Test ROS RMSE for XGB: 0.000407320035155572
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.5204952698501484
# Test ROS RMSE for LM: 0.00044812826895183433
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.3216162757345327
# Test ROS RMSE for RF: 0.000411894941506603
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.351404144879547
# Test ROS RMSE for XGB: 0.0004168169470340325
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.5757278845866565
# Test ROS RMSE for LM: 0.00044890985661102495
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.4496089291043095
# Test ROS RMSE for RF: 0.0004261691679925349
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.4434058961419
# Test ROS RMSE for XGB: 0.0004250871629348043
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.692905896920162
# Test ROS RMSE for LM: 0.00045772892524401575
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.654329671185638
# Test ROS RMSE for RF: 0.0004485697779012826
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.572591782553615
# Test ROS RMSE for XGB: 0.00043842609003736884
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8646561133090596
# Test ROS RMSE for LM: 0.00047360010627343387
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.884230263134814
# Test ROS RMSE for RF: 0.0004700831564523619
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.710275344656005
# Test ROS RMSE for XGB: 0.00045362613650867236
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.07926343060743
# Test ROS RMSE for LM: 0.0004942933977779362
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.086764344922553
# Test ROS RMSE for RF: 0.0004899858296798894
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9850797766960118
# Test ROS RMSE for XGB: 0.0004804743587278291
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.321855995911068
# Test ROS RMSE for LM: 0.0005174968500213825
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.353457728044025
# Test ROS RMSE for RF: 0.0005153906379424028
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.16506483319784
# Test ROS RMSE for XGB: 0.0004985351892635612
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.579758760701277
# Test ROS RMSE for LM: 0.0005417961482928239
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.637355182627494
# Test ROS RMSE for RF: 0.0005436568969395414
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.3617866177173665
# Test ROS RMSE for XGB: 0.0005164248715238657
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.839104376781303
# Test ROS RMSE for LM: 0.000566074907769277
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.8877035168310945
# Test ROS RMSE for RF: 0.0005687872464813341
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.615869027191066
# Test ROS RMSE for XGB: 0.000542194382508626
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.089018670320388
# Test ROS RMSE for LM: 0.0005895973733583397
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.179239867318754
# Test ROS RMSE for RF: 0.0005984002157598349
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.863054021997067
# Test ROS RMSE for XGB: 0.0005659160594412422
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.324961706152297
# Test ROS RMSE for LM: 0.0006121052578875542
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.383123612675023
# Test ROS RMSE for RF: 0.0006154517449898146
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.363507345806964
# Test ROS RMSE for XGB: 0.00041777952721910004
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.649028164659016
# Test ROS RMSE for LM: 0.0004549895382412446
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.586962752850687
# Test ROS RMSE for RF: 0.00044183445815721263
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 1
# t: 2023-05-19 02:22:00
# Number of Training Observations: 53460
# Number of Training Locations: 85
# Number of Features: 16
# Time range Train: ('2023-05-19 02:22:00', '2023-06-16 02:18:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-16 02:23:00', '2023-06-18 02:14:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.4530140168765597
# Test ROS RMSE for XGB: 0.0004270063427698118
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.7806564942390275
# Test ROS RMSE for LM: 0.0004689720412652494
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.4933185067099677
# Test ROS RMSE for RF: 0.000431443247685346
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.4772698579154344
# Test ROS RMSE for XGB: 0.0004325378009470649
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.796064085291974
# Test ROS RMSE for LM: 0.00046790303687130466
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5077951614825658
# Test ROS RMSE for RF: 0.0004337348685927086
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5900895626091534
# Test ROS RMSE for XGB: 0.0004453580421641175
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8733266501147368
# Test ROS RMSE for LM: 0.00047226952951244126
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.643461617157691
# Test ROS RMSE for RF: 0.0004519282254814228
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.584992121703116
# Test ROS RMSE for XGB: 0.00044454067536979893
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.008883132566043
# Test ROS RMSE for LM: 0.0004882064953784914
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.818063964136749
# Test ROS RMSE for RF: 0.0004723192972597166
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7744139074522787
# Test ROS RMSE for XGB: 0.0004692440774283492
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.207417165908808
# Test ROS RMSE for LM: 0.0005138702810009145
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.005563930410048
# Test ROS RMSE for RF: 0.0004970193191497517
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9137572365064415
# Test ROS RMSE for XGB: 0.00048291352167129694
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.463609673461728
# Test ROS RMSE for LM: 0.000545327912636476
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.255424879111154
# Test ROS RMSE for RF: 0.0005261349289160314
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.111413401656587
# Test ROS RMSE for XGB: 0.0005060923912622047
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.762688124628033
# Test ROS RMSE for LM: 0.0005791555393602537
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.604030301070609
# Test ROS RMSE for RF: 0.0005624957979162827
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.299312919267892
# Test ROS RMSE for XGB: 0.0005283027477193875
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.088433839769786
# Test ROS RMSE for LM: 0.0006136938017790326
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.903578350053977
# Test ROS RMSE for RF: 0.0005956811892238646
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.538555349812967
# Test ROS RMSE for XGB: 0.0005555557332418821
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.421215372760579
# Test ROS RMSE for LM: 0.000647820931460287
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.112672834024016
# Test ROS RMSE for RF: 0.0006192710532150344
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.832038779943814
# Test ROS RMSE for XGB: 0.0005904139008921428
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.744832444819817
# Test ROS RMSE for LM: 0.0006807048144766139
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.373282872455741
# Test ROS RMSE for RF: 0.000644223488035246
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.09462264190494
# Test ROS RMSE for XGB: 0.0006190256010066881
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.051769883054818
# Test ROS RMSE for LM: 0.0007118365984956318
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.7708323690913375
# Test ROS RMSE for RF: 0.000683100593674423
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5622896372431603
# Test ROS RMSE for XGB: 0.00044976891832313793
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.943949985241738
# Test ROS RMSE for LM: 0.0004806874751696691
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7401903986428042
# Test ROS RMSE for RF: 0.00046922748319361534
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 2
# t: 2023-05-21 02:22:00
# Number of Training Observations: 53682
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-21 02:22:00', '2023-06-18 02:18:00')
# ----------
# Number of Test Observations: 1056
# Number of Test Locations: 22
# Time range Test: ('2023-06-18 02:22:00', '2023-06-20 02:13:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7600147543723996
# Test ROS RMSE for XGB: 0.0004014436956619375
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.8601108186218176
# Test ROS RMSE for LM: 0.00041173220710837596
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4792815760518097
# Test ROS RMSE for RF: 0.00033896319068428
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.747143541951394
# Test ROS RMSE for XGB: 0.00040438822153544786
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.8135656303375787
# Test ROS RMSE for LM: 0.00040753960190826065
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4435793624133852
# Test ROS RMSE for RF: 0.0003362714596908754
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.661898989881096
# Test ROS RMSE for XGB: 0.0003950874573184444
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7207393409228513
# Test ROS RMSE for LM: 0.0004004680844082844
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4256258764118357
# Test ROS RMSE for RF: 0.00033075066171793987
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.4504268485843093
# Test ROS RMSE for XGB: 0.0003639984235614143
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.6621147362819526
# Test ROS RMSE for LM: 0.0003959013639558716
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.419705337774087
# Test ROS RMSE for RF: 0.0003347622491913112
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.4045278669644015
# Test ROS RMSE for XGB: 0.0003627187355974439
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.631144626100675
# Test ROS RMSE for LM: 0.0003918007474336858
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.3613158997934556
# Test ROS RMSE for RF: 0.0003248292263302716
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.3713526810825063
# Test ROS RMSE for XGB: 0.0003596219744645227
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.6284577449724082
# Test ROS RMSE for LM: 0.0003881238636073231
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.408619614529809
# Test ROS RMSE for RF: 0.0003274310071028416
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.2394051289800525
# Test ROS RMSE for XGB: 0.0003393962816267391
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.6555019348776314
# Test ROS RMSE for LM: 0.00038557520141024344
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.407784656252419
# Test ROS RMSE for RF: 0.00032638120606221063
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.18161476301625
# Test ROS RMSE for XGB: 0.00032179178264903096
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7114624790366237
# Test ROS RMSE for LM: 0.0003850021268613934
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.442470847729068
# Test ROS RMSE for RF: 0.0003282830419526998
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.2218532454302076
# Test ROS RMSE for XGB: 0.0003278459079257167
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.791542425226819
# Test ROS RMSE for LM: 0.0003869858322340751
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.489842032584898
# Test ROS RMSE for RF: 0.0003328232186590732
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.230518677905393
# Test ROS RMSE for XGB: 0.00032005710600041575
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.88815848614396
# Test ROS RMSE for LM: 0.00039157559755365317
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.621819683701074
# Test ROS RMSE for RF: 0.0003390019921945642
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.301886458113049
# Test ROS RMSE for XGB: 0.00032364413995516784
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9945269542198223
# Test ROS RMSE for LM: 0.0003984276003426018
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.6700967348935696
# Test ROS RMSE for RF: 0.0003472936269352858
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.4159932846150696
# Test ROS RMSE for XGB: 0.0003581528405524187
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.665256610683571
# Test ROS RMSE for LM: 0.00038944363611349744
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.3781744198336847
# Test ROS RMSE for RF: 0.0003277213375146368
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 3
# t: 2023-05-23 02:22:00
# Number of Training Observations: 53316
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-23 02:22:00', '2023-06-20 02:18:00')
# ----------
# Number of Test Observations: 997
# Number of Test Locations: 21
# Time range Test: ('2023-06-20 02:20:00', '2023-06-22 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.6866344737030547
# Test ROS RMSE for XGB: 0.0005324311157482426
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.031487665710085
# Test ROS RMSE for LM: 0.000599924102659289
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6911779746881273
# Test ROS RMSE for RF: 0.0005437519674750195
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.6535182657735104
# Test ROS RMSE for XGB: 0.0005246844462283664
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.9905275549894754
# Test ROS RMSE for LM: 0.0005924678424363208
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6992116528011785
# Test ROS RMSE for RF: 0.000540917907936811
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.610764750773799
# Test ROS RMSE for XGB: 0.0005148915635890958
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.9034364740724095
# Test ROS RMSE for LM: 0.0005757496222516424
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6630229254865374
# Test ROS RMSE for RF: 0.000538920545355065
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.6128050305128023
# Test ROS RMSE for XGB: 0.0005125407062191076
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.846187071657227
# Test ROS RMSE for LM: 0.0005630665364881748
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6270851060316702
# Test ROS RMSE for RF: 0.0005239382103760776
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5705236905047797
# Test ROS RMSE for XGB: 0.0005043257185448176
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.818787319188396
# Test ROS RMSE for LM: 0.0005540861894063396
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6819623709356506
# Test ROS RMSE for RF: 0.0005274045462809547
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5787850211853813
# Test ROS RMSE for XGB: 0.0005003417380566183
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.823125626284081
# Test ROS RMSE for LM: 0.0005485897436632094
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.727987122886597
# Test ROS RMSE for RF: 0.000529137185446705
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.654326091891497
# Test ROS RMSE for XGB: 0.0005009897774025954
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.858595294608561
# Test ROS RMSE for LM: 0.0005461366403307237
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.836009103515766
# Test ROS RMSE for RF: 0.0005355416368572568
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7173703031853287
# Test ROS RMSE for XGB: 0.0005026227454066213
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.9216501771206116
# Test ROS RMSE for LM: 0.0005462316220990535
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.00533759182877
# Test ROS RMSE for RF: 0.0005508480433049185
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.791050893097931
# Test ROS RMSE for XGB: 0.0005092453235410123
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.0056124571574205
# Test ROS RMSE for LM: 0.0005483997525995744
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.146781532581906
# Test ROS RMSE for RF: 0.0005626573650370595
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9783121299542152
# Test ROS RMSE for XGB: 0.0005270197415004318
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.102461564567016
# Test ROS RMSE for LM: 0.0005521346394462707
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.259844026088102
# Test ROS RMSE for RF: 0.0005643526195108336
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.058800934796559
# Test ROS RMSE for XGB: 0.0005256539158441364
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.205959157767851
# Test ROS RMSE for LM: 0.0005570015208691819
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.387595805104495
# Test ROS RMSE for RF: 0.0005744924045437771
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5991417845516804
# Test ROS RMSE for XGB: 0.0005143626443637389
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8622925008410425
# Test ROS RMSE for LM: 0.0005657680032039884
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.669984962247059
# Test ROS RMSE for RF: 0.0005336983453340565
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 4
# t: 2023-05-25 02:22:00
# Number of Training Observations: 53636
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-25 02:22:00', '2023-06-22 02:18:00')
# ----------
# Number of Test Observations: 1057
# Number of Test Locations: 22
# Time range Test: ('2023-06-22 02:20:00', '2023-06-24 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.2667777688247055
# Test ROS RMSE for XGB: 0.000574971722792523
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.4377537012955575
# Test ROS RMSE for LM: 0.0006357885573980856
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.116265083591589
# Test ROS RMSE for RF: 0.0005592921256250769
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.364957387641238
# Test ROS RMSE for XGB: 0.0006038154217859954
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.441153394733832
# Test ROS RMSE for LM: 0.0006359425547162403
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.089665380621646
# Test ROS RMSE for RF: 0.000559994634514319
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.455779326029563
# Test ROS RMSE for XGB: 0.000596958197939464
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.469390800777603
# Test ROS RMSE for LM: 0.0006369839292625597
# Fitting RF
# ...
# Predicting with RF
# Test RMSE for RF: 5.323718390093078
# Test ROS RMSE for RF: 0.0006785202885932996
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.746522388430418
# Test ROS RMSE for XGB: 0.0007144553591111495
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.012817939408653
# Test ROS RMSE for LM: 0.0007602500566555713
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.95132673562056
# Test ROS RMSE for RF: 0.000735305624063083
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.938769780953494
# Test ROS RMSE for XGB: 0.0007346531909741109
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.3234924086979065
# Test ROS RMSE for LM: 0.000784618442264863
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.164908445835279
# Test ROS RMSE for RF: 0.0007534855915285664
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.297575486089002
# Test ROS RMSE for XGB: 0.0007662079387479195
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.59935120551553
# Test ROS RMSE for LM: 0.0008067810084183575
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.600084846212024
# Test ROS RMSE for RF: 0.0007954315217415838
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.547258989673452
# Test ROS RMSE for XGB: 0.0007899219467499911
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.844335050058601
# Test ROS RMSE for LM: 0.0008273129709764474
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.829187004722078
# Test ROS RMSE for RF: 0.0008181087602684934
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.649653102403376
# Test ROS RMSE for XGB: 0.0006189562448588445
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.47667448262337
# Test ROS RMSE for LM: 0.000640618730967025
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.473406299698499
# Test ROS RMSE for RF: 0.000619284534994947
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 166
# t: 2024-04-13 02:22:00
# Number of Training Observations: 55710
# Number of Training Locations: 88
# Number of Features: 16
# Time range Train: ('2024-04-13 02:22:00', '2024-05-11 02:17:00')
# ----------
# Number of Test Observations: 1007
# Number of Test Locations: 21
# Time range Test: ('2024-05-11 02:24:00', '2024-05-13 02:16:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.011240813315886
# Test ROS RMSE for XGB: 0.0006586828439166485
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.294298624106198
# Test ROS RMSE for LM: 0.0005792102701068101
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.1565864457643205
# Test ROS RMSE for RF: 0.0006646324297198983
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.999990000583463
# Test ROS RMSE for XGB: 0.0006540140514225181
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.343509888562614
# Test ROS RMSE for LM: 0.0005843490113472695
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.243064849861005
# Test ROS RMSE for RF: 0.0006762180017991478
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.174794556348021
# Test ROS RMSE for XGB: 0.0006728173870126951
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.527795665341463
# Test ROS RMSE for LM: 0.0006029330860844804
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.472650121514921
# Test ROS RMSE for RF: 0.0007016423724529357
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.359166800355779
# Test ROS RMSE for XGB: 0.0006875709205158163
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.7797073060566495
# Test ROS RMSE for LM: 0.0006276643787674084
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.629153866074367
# Test ROS RMSE for RF: 0.0007157851216312025
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.537309845054127
# Test ROS RMSE for XGB: 0.0007062474832718273
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.081814846389621
# Test ROS RMSE for LM: 0.0006567973587440789
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.009190385462574
# Test ROS RMSE for RF: 0.0007528811098178458
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.69205144183761
# Test ROS RMSE for XGB: 0.0007194168734007043
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.408354786000273
# Test ROS RMSE for LM: 0.0006877126896964948
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.231189585054851
# Test ROS RMSE for RF: 0.0007761977348876255
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.973488028765393
# Test ROS RMSE for XGB: 0.0007461203815858404
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.734901172736303
# Test ROS RMSE for LM: 0.0007181026341251112
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.495420162005752
# Test ROS RMSE for RF: 0.000809806797312891
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.036519718730254
# Test ROS RMSE for XGB: 0.0007507253282969748
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.047123938715035
# Test ROS RMSE for LM: 0.0007468697874731475
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.807602959154951
# Test ROS RMSE for RF: 0.0008418389830366716
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.476830298610317
# Test ROS RMSE for XGB: 0.0007967015020123138
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.334310645414358
# Test ROS RMSE for LM: 0.0007736525921882641
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.042223650065042
# Test ROS RMSE for RF: 0.0008681984436779727
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.823844614911178
# Test ROS RMSE for XGB: 0.0008313745717666537
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.592089871571689
# Test ROS RMSE for LM: 0.000798573188935022
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.24825333872714
# Test ROS RMSE for RF: 0.000889132828719474
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.825408266110708
# Test ROS RMSE for XGB: 0.000832376624421581
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.822875461389665
# Test ROS RMSE for LM: 0.0008220313426691777
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.630325505265886
# Test ROS RMSE for RF: 0.000937889098946809
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 3, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 100, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.316558012123688
# Test ROS RMSE for XGB: 0.0006840233166497237
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.702559783360975
# Test ROS RMSE for LM: 0.0006215299670002302
# Fitting RF
# Training RF with params: {'n_estimators': 25, 'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.577752148822406
# Test ROS RMSE for RF: 0.0007108730251151436

# %%
# # Number of replications
# nreps = 5

# # Get unique month and year combos in the data
# month_year = df.index.to_period('M').unique()
# print(month_year)
# reproducibility.set_seed(42)

# for i in range(0, nreps):
#     for my in month_year:
#         print("~"*80)
#         month = my.month
#         year = my.year
#         print(f"Splitting data for month: {my}")
#         df_temp = df[(df.index.month == month) & (df.index.year == year)]
#         print(f"Total observations: {df_temp.shape}")
#         X_train, X_test, y_train, y_test = train_test_split_spacetime(
#             df_temp, 
#             test_days = 2,
#             spatial_test_frac = 0.2,
#             verbose = True
#         )
#         X_train = X_train[cols]
#         X_test = X_test[cols]
#         for l in loss_dict:
#             print("~"*50)
#             print(f"Running models for loss func: {l}")
#             if loss_dict[l]['w_func'] is not None:
#                 weights = loss_dict[l]['w_func'](y_train)
#             else:
#                 weights = None
#             # Reinitialize models dictionary to prevent multiple fitting iterations
#             # if True:
#             #     models = initialize_models()
#             for mod in models:
#                 print(f"Fitting {mod}")
#                 models[mod].fit(X_train, y_train, weights)
#                 preds = models[mod].predict(X_test)
#                 loss_dict[l][f"errs"][mod]["rmse_test"].append(rmse(preds, y_test))
#                 loss_dict[l][f"errs"][mod]["rmse_test_ROS"].append(rmse(ros(preds), ros(y_test)))
#                 print(f"Test RMSE for {mod}: {rmse(preds, y_test)}")
#                 print(f"Test ROS RMSE for {mod}: {rmse(ros(preds), ros(y_test))}")

# %%
results_fm = []
results_ros = []
for l in loss_dict:
    for mod in loss_dict[l]["errs"]:
        errs = loss_dict[l]["errs"][mod]['rmse_test']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_fm.append(pd.DataFrame(temp))
        errs = loss_dict[l]["errs"][mod]['rmse_test_ROS']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test_ROS'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_ros.append(pd.DataFrame(temp))

# %%
results_fm = pd.concat(results_fm)
results_fm
# Out:
#          RMSE Loss Model                   t
# 0    3.233430  MSE   XGB 2023-05-17 02:22:00
# 1    3.453014  MSE   XGB 2023-05-19 02:22:00
# 2    2.760015  MSE   XGB 2023-05-21 02:22:00
# 3    3.686634  MSE   XGB 2023-05-23 02:22:00
# 4    4.266778  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  6.368772  ROS    RF 2024-04-05 02:22:00
# 163  3.728581  ROS    RF 2024-04-07 02:22:00
# 164  4.419576  ROS    RF 2024-04-09 02:22:00
# 165  4.473406  ROS    RF 2024-04-11 02:22:00
# 166  5.577752  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
results_ros = pd.concat(results_ros)
results_ros
# Out:
#          RMSE Loss Model                   t
# 0    0.000399  MSE   XGB 2023-05-17 02:22:00
# 1    0.000427  MSE   XGB 2023-05-19 02:22:00
# 2    0.000401  MSE   XGB 2023-05-21 02:22:00
# 3    0.000532  MSE   XGB 2023-05-23 02:22:00
# 4    0.000575  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  0.000850  ROS    RF 2024-04-05 02:22:00
# 163  0.000453  ROS    RF 2024-04-07 02:22:00
# 164  0.000607  ROS    RF 2024-04-09 02:22:00
# 165  0.000619  ROS    RF 2024-04-11 02:22:00
# 166  0.000711  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
# Write Dataframe
with open(osp.join("outputs", "results_fm.pkl"), 'wb') as handle:
    pickle.dump(results_fm, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(osp.join("outputs", "results_ros.pkl"), 'wb') as handle:
    pickle.dump(results_ros, handle, protocol=pickle.HIGHEST_PROTOCOL)
