# %% [markdown]
# # Test Loss Functions on Multiple Models

# %%
import sys
sys.path.append('src')
import pandas as pd
import numpy as np
import xgboost as xg
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from utils import create_exp_function, loss_setup, initialize_models
import yaml
import pickle
import os.path as osp
from datetime import timedelta
import matplotlib.pyplot as plt
# Local modules
from data_funcs import train_test_split_spacetime
from fmda_models import LM, XGB, RF
from metrics import ros_0wind, ros_3wind, rmse
import reproducibility

# %% [markdown]
# ## Read Data

# %%
df = pd.read_pickle("data/raws_df.pkl")
df = df.dropna()
df.columns
# Out:
# Index(['Ew', 'Ed', 'temp', 'rh', 'rain', 'precip_accum', 'fm', 'wind', 'solar',
#        'time_raws', 'STID', 'lat', 'lon', 'elev', 'hour', 'doy', 'date'],
#       dtype='object')

# %%
df
# Out:
#                             Ew         Ed     temp    rh  rain  precip_accum  \
# 2023-05-17 03:09:00  13.147834  14.552503  284.817  48.0  0.00       470.408
# 2023-05-17 04:09:00  13.247513  14.652182  284.261  48.0  0.00       470.408
# 2023-05-17 05:09:00  12.876054  14.274707  284.261  46.0  0.00       470.408
# 2023-05-17 06:09:00  13.446692  14.851361  283.150  48.0  0.00       470.408
# 2023-05-17 07:09:00  14.000874  15.412836  283.150  51.0  0.00       470.408
# ...                        ...        ...      ...   ...   ...           ...
# 2024-05-14 19:17:00   5.988904   7.156126  293.706  20.0  0.00         6.096
# 2024-05-14 20:17:00   9.688784  11.031949  290.372  35.0  0.00         6.096
# 2024-05-14 21:17:00  11.794500  13.189754  289.261  45.0  5.08        11.176
# 2024-05-14 22:17:00   7.987530   9.267817  292.039  28.0  0.00        11.176
# 2024-05-14 23:17:00   7.970651   9.239580  290.928  27.0  0.00        11.176
#
#                       fm   wind  solar           time_raws   STID       lat  \
# 2023-05-17 03:09:00  7.5  1.790    1.0 2023-05-17 03:09:00  CPTC2  38.45944
# 2023-05-17 04:09:00  8.1  1.790    0.0 2023-05-17 04:09:00  CPTC2  38.45944
# 2023-05-17 05:09:00  8.6  1.790    0.0 2023-05-17 05:09:00  CPTC2  38.45944
# 2023-05-17 06:09:00  9.2  1.790    0.0 2023-05-17 06:09:00  CPTC2  38.45944
# 2023-05-17 07:09:00  9.6  1.790    0.0 2023-05-17 07:09:00  CPTC2  38.45944
# ...                  ...    ...    ...                 ...    ...       ...
# 2024-05-14 19:17:00  9.4  1.343  970.0 2024-05-14 19:17:00  TT815  37.52272
# 2024-05-14 20:17:00  7.3  0.448  426.0 2024-05-14 20:17:00  TT815  37.52272
# 2024-05-14 21:17:00  8.0  1.343  594.0 2024-05-14 21:17:00  TT815  37.52272
# 2024-05-14 22:17:00  8.0  1.790  742.0 2024-05-14 22:17:00  TT815  37.52272
# 2024-05-14 23:17:00  8.2  0.895  362.0 2024-05-14 23:17:00  TT815  37.52272
#
#                            lon  elev  hour  doy                date
# 2023-05-17 03:09:00 -109.04694  8088     3  137 2023-05-17 03:09:00
# 2023-05-17 04:09:00 -109.04694  8088     4  137 2023-05-17 04:09:00
# 2023-05-17 05:09:00 -109.04694  8088     5  137 2023-05-17 05:09:00
# 2023-05-17 06:09:00 -109.04694  8088     6  137 2023-05-17 06:09:00
# 2023-05-17 07:09:00 -109.04694  8088     7  137 2023-05-17 07:09:00
# ...                        ...   ...   ...  ...                 ...
# 2024-05-14 19:17:00 -108.48178  7576    19  135 2024-05-14 19:17:00
# 2024-05-14 20:17:00 -108.48178  7576    20  135 2024-05-14 20:17:00
# 2024-05-14 21:17:00 -108.48178  7576    21  135 2024-05-14 21:17:00
# 2024-05-14 22:17:00 -108.48178  7576    22  135 2024-05-14 22:17:00
# 2024-05-14 23:17:00 -108.48178  7576    23  135 2024-05-14 23:17:00
#
# [875127 rows x 17 columns]

# %% [markdown]
# ## Setup Models

# %%
with open('models/params.yaml', 'r') as file:
    params = yaml.safe_load(file)

params
# Out:
# {'xgb': {'max_depth': 4,
#   'eta': 0.1,
#   'min_child_weight': 1,
#   'subsample': 0.8,
#   'colsample_bytree': 0.9,
#   'scale_pos_weight': 1,
#   'n_estimators': 120,
#   'gamma': 0.1},
#  'rf': {'n_estimators': 50,
#   'criterion': 'squared_error',
#   'max_depth': 8,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 0.8,
#   'bootstrap': True,
#   'max_samples': None,
#   'random_state': None,
#   'verbose': 0,
#   'warm_start': False},
#  'mlp': {'hidden_units': 10,
#   'activation': 'relu',
#   'optimizer': 'adam',
#   'epochs': 10,
#   'batch_size': 32,
#   'validation_split': 0.2,
#   'dropout': 0.2,
#   'learning_rate': 0.001},
#  'lm': {'fit_intercept': True}}

# %%
weight_grid=np.round(np.linspace(0.01, .25, 10), 4)
models, loss_dict = loss_setup(params=params, ws=weight_grid)
# loss_dict

# %% [markdown]
# ## Run Analysis

# %%
## COLUMNS SUBSET
cols = ["Ed", "rain", "wind", "solar", "hour", "doy", "lat", "lon", 'elev']

# # Get unique month and year combos in the data
# month_year = df.index.to_period('M').unique()
# print(month_year)

reproducibility.set_seed(42)

# my = month_year[1]
# month = my.month
# year = my.year
# print(f"Splitting data for month: {my}")
# df_temp = df[(df.index.month == month) & (df.index.year == year)]
# print(f"Total observations: {df_temp.shape}")
# X_train, X_test, y_train, y_test = train_test_split_spacetime(
#     df_temp, 
#     test_days = 2,
#     spatial_test_frac = 0.2,
#     verbose = True
# )
# X_train = X_train[cols]
# X_test = X_test[cols]
# Out:
# resetting random seeds to 42

# %% [markdown]
# For each loss function and each model, we will collect 2 arrays of errors on the test set. One for the RMSE on the test fuel moisture observations, and another one on the RMSE for the same observations transformed to ROS.

# %%
t = df.index.min()
i = 0
tdelta = 2 # number of days to shift train/test period
while t <= (df.index.max() - timedelta(days = 30)):
    print("~"*50)
    print(f"Iteration: {i}")
    print(f"t: {t}")
    # Build train/test from 30 day period after t
    df_temp = df[
        (df.index >= t) & (df.index < (t + timedelta(days=30)))
    ]
    X_train, X_test, y_train, y_test = train_test_split_spacetime(
        df_temp, 
        test_days = 2,
        spatial_test_frac = 0.2,
        verbose = True
    )
    X_train = X_train[cols]
    X_test = X_test[cols]
    # Run models
    # Reinitialize models dictionary to prevent multiple fitting iterations
    if True:
        models = initialize_models(params)
    for l in loss_dict:
        print("~"*50)
        print(f"Running models for loss func: {l}")
        if loss_dict[l]['w_func'] is not None:
            weights = loss_dict[l]['w_func'](y_train)
        else:
            weights = None

        for mod in models:
            print(f"Fitting {mod}")
            models[mod].fit(X_train, y_train, weights)
            preds = models[mod].predict(X_test)
            loss_dict[l][f"errs"][mod]["t"].append(t)
            loss_dict[l][f"errs"][mod]["rmse_test"].append(rmse(preds, y_test))
            loss_dict[l][f"errs"][mod]["rmse_test_ROS"].append(rmse(ros_3wind(preds), ros_3wind(y_test)))
            print(f"Test RMSE for {mod}: {rmse(preds, y_test)}")
            print(f"Test ROS RMSE for {mod}: {rmse(ros_3wind(preds), ros_3wind(y_test))}")

    # # Iterate test period by 2 so no overlap
    i+= 1 # iteration counter
    t = t + timedelta(days=tdelta)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 0
# t: 2023-05-17 02:22:00
# Number of Training Observations: 52180
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-17 02:22:00', '2023-06-14 02:18:00')
# ----------
# Number of Test Observations: 1052
# Number of Test Locations: 22
# Time range Test: ('2023-06-14 02:20:00', '2023-06-16 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.857785409141178
# Test ROS RMSE for XGB: 0.006082616282438361
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.182792561172982
# Test ROS RMSE for LM: 0.0069023249236351775
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.753915087518648
# Test ROS RMSE for RF: 0.005934752815070952
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.913170429067372
# Test ROS RMSE for XGB: 0.006183456511564428
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.166002332431029
# Test ROS RMSE for LM: 0.0068400846125014425
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7419887381654213
# Test ROS RMSE for RF: 0.005925093186480432
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.893632142889069
# Test ROS RMSE for XGB: 0.006159150607461339
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.1550814307223884
# Test ROS RMSE for LM: 0.006733185121670884
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.759044116697427
# Test ROS RMSE for RF: 0.0059838711508380365
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9109797122276304
# Test ROS RMSE for XGB: 0.006194415772772831
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.195112525019072
# Test ROS RMSE for LM: 0.006722525449775049
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.8100367256770937
# Test ROS RMSE for RF: 0.006056645185723935
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8541757182060743
# Test ROS RMSE for XGB: 0.006122661954815028
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.287666551283418
# Test ROS RMSE for LM: 0.006805504088391422
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.91216590962803
# Test ROS RMSE for RF: 0.006200385860180517
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.845080728032745
# Test ROS RMSE for XGB: 0.006141018918247173
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.429973060461246
# Test ROS RMSE for LM: 0.006969296201373649
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.9824717661061997
# Test ROS RMSE for RF: 0.00630073600822512
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.930276093303621
# Test ROS RMSE for XGB: 0.006263172311504716
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.613253899291186
# Test ROS RMSE for LM: 0.007190508626006392
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.1265479598169525
# Test ROS RMSE for RF: 0.006498671479437133
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.066536715673182
# Test ROS RMSE for XGB: 0.006440650602054204
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.8267640271601655
# Test ROS RMSE for LM: 0.0074473967836082774
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.343438707091996
# Test ROS RMSE for RF: 0.006769614463416624
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.226750131872196
# Test ROS RMSE for XGB: 0.0066232174910498326
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.056314051361953
# Test ROS RMSE for LM: 0.007718660855203001
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.4335131445574
# Test ROS RMSE for RF: 0.006912733522947673
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.413618369341059
# Test ROS RMSE for XGB: 0.006896413076434987
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.288771582513835
# Test ROS RMSE for LM: 0.007991704342687776
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.505731777136854
# Test ROS RMSE for RF: 0.006983735697860819
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.615566637911952
# Test ROS RMSE for XGB: 0.007153630771002023
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.516604048205675
# Test ROS RMSE for LM: 0.00825998876537297
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.771121124194428
# Test ROS RMSE for RF: 0.007312938255297585
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7574024519265126
# Test ROS RMSE for XGB: 0.006007220955542329
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.1692618449678625
# Test ROS RMSE for LM: 0.006721744003530483
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7750175399343435
# Test ROS RMSE for RF: 0.006032164969258904
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 1
# t: 2023-05-19 02:22:00
# Number of Training Observations: 52816
# Number of Training Locations: 85
# Number of Features: 16
# Time range Train: ('2023-05-19 02:22:00', '2023-06-16 02:18:00')
# ----------
# Number of Test Observations: 1010
# Number of Test Locations: 21
# Time range Test: ('2023-06-16 02:20:00', '2023-06-18 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.3015524784921766
# Test ROS RMSE for XGB: 0.005583501371013773
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.7633556880456713
# Test ROS RMSE for LM: 0.0063110685231074415
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.1984901499734586
# Test ROS RMSE for RF: 0.0052137361282592895
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.327433084567352
# Test ROS RMSE for XGB: 0.005635811542326263
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.75524683458989
# Test ROS RMSE for LM: 0.006250318881615425
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.215190025573645
# Test ROS RMSE for RF: 0.005224448860113645
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.411555952455947
# Test ROS RMSE for XGB: 0.00575446298080739
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.773025887353199
# Test ROS RMSE for LM: 0.006184309580619695
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.243872316623641
# Test ROS RMSE for RF: 0.005338174051474547
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.4664300754275716
# Test ROS RMSE for XGB: 0.0058553234856768355
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8553635375081448
# Test ROS RMSE for LM: 0.006277362609046791
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.3098795021838607
# Test ROS RMSE for RF: 0.005475563184337965
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.446878947696481
# Test ROS RMSE for XGB: 0.005797418562488596
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.008301439918732
# Test ROS RMSE for LM: 0.006520139548560529
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.4158134235960143
# Test ROS RMSE for RF: 0.005685729283446097
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5965453463977806
# Test ROS RMSE for XGB: 0.006048301933352227
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.228003454994552
# Test ROS RMSE for LM: 0.006875296803301698
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.538240504130865
# Test ROS RMSE for RF: 0.005872557903763109
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.782659654431151
# Test ROS RMSE for XGB: 0.00633502636931053
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.500026510300356
# Test ROS RMSE for LM: 0.007288991794159717
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7110931906357525
# Test ROS RMSE for RF: 0.006179877643395883
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.8008515706841086
# Test ROS RMSE for XGB: 0.006290004909337662
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.807193743224272
# Test ROS RMSE for LM: 0.007718871769500726
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.8999619298390416
# Test ROS RMSE for RF: 0.006498348736793271
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.100185261652485
# Test ROS RMSE for XGB: 0.006769309678077248
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.128615803170402
# Test ROS RMSE for LM: 0.008136916231026452
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.118121012699993
# Test ROS RMSE for RF: 0.006789933089646843
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.28903561933553
# Test ROS RMSE for XGB: 0.007009842375944087
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.446521700808262
# Test ROS RMSE for LM: 0.008524774495122747
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.333764630913531
# Test ROS RMSE for RF: 0.007079019251046628
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.500945912792615
# Test ROS RMSE for XGB: 0.007331563961395642
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.751859122961725
# Test ROS RMSE for LM: 0.008883407775862395
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.579569239819199
# Test ROS RMSE for RF: 0.007409143031296161
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.3182434006721753
# Test ROS RMSE for XGB: 0.005630271222851937
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8108449980711616
# Test ROS RMSE for LM: 0.006229791575503945
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.3067505193484226
# Test ROS RMSE for RF: 0.005527075763375829
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 2
# t: 2023-05-21 02:22:00
# Number of Training Observations: 53533
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-21 02:22:00', '2023-06-18 02:18:00')
# ----------
# Number of Test Observations: 1057
# Number of Test Locations: 22
# Time range Test: ('2023-06-18 02:20:00', '2023-06-20 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.768665717743677
# Test ROS RMSE for XGB: 0.0050143402783996305
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.877222486065003
# Test ROS RMSE for LM: 0.0056508060351835926
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.6785359633891317
# Test ROS RMSE for RF: 0.0043290373778684926
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.767381848897209
# Test ROS RMSE for XGB: 0.00503336426217146
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.901903270102617
# Test ROS RMSE for LM: 0.005730009193826834
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.6871906033847623
# Test ROS RMSE for RF: 0.004353298129192348
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6593545827654297
# Test ROS RMSE for XGB: 0.004854820865513852
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9836092620017363
# Test ROS RMSE for LM: 0.00592173145189693
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.669160817334902
# Test ROS RMSE for RF: 0.004282197452680847
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5873977980460716
# Test ROS RMSE for XGB: 0.004655032943009843
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0777093608413044
# Test ROS RMSE for LM: 0.006062799285690404
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7237327128295723
# Test ROS RMSE for RF: 0.004347913006140896
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.591789323524627
# Test ROS RMSE for XGB: 0.004661050575076663
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1790973465316656
# Test ROS RMSE for LM: 0.006151289605915362
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.738225449786433
# Test ROS RMSE for RF: 0.0043749807889037476
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.603512656514162
# Test ROS RMSE for XGB: 0.004587156210291707
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.2858568164190523
# Test ROS RMSE for LM: 0.006205467224758671
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.860955464640637
# Test ROS RMSE for RF: 0.004537324417833371
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.598667018433579
# Test ROS RMSE for XGB: 0.004518302320530328
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.39688173850165
# Test ROS RMSE for LM: 0.0062483832609204724
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8806187263615657
# Test ROS RMSE for RF: 0.004521093804677289
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6575553603267936
# Test ROS RMSE for XGB: 0.004507452139382768
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.5116502881062264
# Test ROS RMSE for LM: 0.0062962865994019195
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.927815929685836
# Test ROS RMSE for RF: 0.004579621682153595
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.744125873088478
# Test ROS RMSE for XGB: 0.004567657856801695
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.6275305222615697
# Test ROS RMSE for LM: 0.006356504019719439
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.0333477294582782
# Test ROS RMSE for RF: 0.00473140027348636
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.817206220892653
# Test ROS RMSE for XGB: 0.004634151003889556
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.7415410382651166
# Test ROS RMSE for LM: 0.006432574318025942
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.1124310635670076
# Test ROS RMSE for RF: 0.00482834039058072
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.90701771050601
# Test ROS RMSE for XGB: 0.004747327437152233
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8522670207272003
# Test ROS RMSE for LM: 0.006522503747657013
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.2106131017084167
# Test ROS RMSE for RF: 0.004957111918214241
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.61422782786355
# Test ROS RMSE for XGB: 0.004770055307118987
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.010146165914839
# Test ROS RMSE for LM: 0.005894586864689315
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7188223015343485
# Test ROS RMSE for RF: 0.004380237141764163
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 3
# t: 2023-05-23 02:22:00
# Number of Training Observations: 53883
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-23 02:22:00', '2023-06-20 02:18:00')
# ----------
# Number of Test Observations: 960
# Number of Test Locations: 20
# Time range Test: ('2023-06-20 02:26:00', '2023-06-22 02:12:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.432499919553732
# Test ROS RMSE for XGB: 0.008346046134374435
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.557507349534281
# Test ROS RMSE for LM: 0.008083581681219207
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.2812012960448986
# Test ROS RMSE for RF: 0.007954899963841182
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.4263456824728307
# Test ROS RMSE for XGB: 0.008326552937490702
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.4820477531323015
# Test ROS RMSE for LM: 0.00793282559864699
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.2046665175708196
# Test ROS RMSE for RF: 0.00781983430362691
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.3517474992673297
# Test ROS RMSE for XGB: 0.007958592838575904
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.3137472234485643
# Test ROS RMSE for LM: 0.007610499180474997
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.095229670687639
# Test ROS RMSE for RF: 0.007650820992078289
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.3078056994218845
# Test ROS RMSE for XGB: 0.008073398289508697
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1862875891666946
# Test ROS RMSE for LM: 0.007355618288013966
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.9918384174768953
# Test ROS RMSE for RF: 0.007423737779725411
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.1027342539156724
# Test ROS RMSE for XGB: 0.007871929161953877
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0951706591080392
# Test ROS RMSE for LM: 0.007138407714123653
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.9129616527924003
# Test ROS RMSE for RF: 0.007254445793264594
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.901903395560904
# Test ROS RMSE for XGB: 0.0074464856081776585
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0413751662779114
# Test ROS RMSE for LM: 0.006956754825730187
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.857516349880075
# Test ROS RMSE for RF: 0.007107959514172323
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.872044546096497
# Test ROS RMSE for XGB: 0.00742111541936971
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0250810803025763
# Test ROS RMSE for LM: 0.0068118918104112525
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.825127924826796
# Test ROS RMSE for RF: 0.007001525833499203
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.880191900522291
# Test ROS RMSE for XGB: 0.007324536717793602
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0433592497395288
# Test ROS RMSE for LM: 0.006701920071937107
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.851671988961363
# Test ROS RMSE for RF: 0.007226610231465662
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.9467882589672447
# Test ROS RMSE for XGB: 0.007418612157390971
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.090130991766866
# Test ROS RMSE for LM: 0.00662796560915528
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8468088733853794
# Test ROS RMSE for RF: 0.007073668822174862
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.9131954613760076
# Test ROS RMSE for XGB: 0.007148856022012308
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.156979175917023
# Test ROS RMSE for LM: 0.00658131717305659
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8559936358342055
# Test ROS RMSE for RF: 0.006871364915003389
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.9628794253037265
# Test ROS RMSE for XGB: 0.0072061554344742835
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.236341234138941
# Test ROS RMSE for LM: 0.0065550038253664265
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.94691452291733
# Test ROS RMSE for RF: 0.007013207733234032
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.927205835483328
# Test ROS RMSE for XGB: 0.007506163388858625
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.2437522172164566
# Test ROS RMSE for LM: 0.0074663883221136795
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.995680583922978
# Test ROS RMSE for RF: 0.007408882738282471
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 4
# t: 2023-05-25 02:22:00
# Number of Training Observations: 53742
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-25 02:22:00', '2023-06-22 02:18:00')
# ----------
# Number of Test Observations: 1055
# Number of Test Locations: 22
# Time range Test: ('2023-06-22 02:22:00', '2023-06-24 02:13:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.353252566230686
# Test ROS RMSE for XGB: 0.007605972890911912
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.026241424359954
# Test ROS RMSE for LM: 0.007121587066294775
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.482177486221236
# Test ROS RMSE for RF: 0.0063489877073870295
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.360886481493305
# Test ROS RMSE for XGB: 0.007647056979450804
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.044642918631162
# Test ROS RMSE for LM: 0.007149074368217833
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5161119442934994
# Test ROS RMSE for RF: 0.006421542155740837
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.525585271396032
# Test ROS RMSE for XGB: 0.0077915977160153554
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.129888190667371
# Test ROS RMSE for LM: 0.0072691486145247805
# Fitting RF
# ...
# Predicting with RF
# Test RMSE for RF: 4.680335061339715
# Test ROS RMSE for RF: 0.007383964579279074
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.045354411689481
# Test ROS RMSE for XGB: 0.007670726442876451
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.224472786762091
# Test ROS RMSE for LM: 0.008182158621064634
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.8674667867737105
# Test ROS RMSE for RF: 0.007563170726361654
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.132150236400106
# Test ROS RMSE for XGB: 0.007737639270489979
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.470705748401219
# Test ROS RMSE for LM: 0.008369444798074471
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.081281791498787
# Test ROS RMSE for RF: 0.007813378009819173
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.319488502536852
# Test ROS RMSE for XGB: 0.007987179333900392
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.699700638619178
# Test ROS RMSE for LM: 0.008565899345077834
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.288180747361962
# Test ROS RMSE for RF: 0.008068917734573133
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.533125387514873
# Test ROS RMSE for XGB: 0.008210880698410018
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.909818995524931
# Test ROS RMSE for LM: 0.008771589505256095
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.466289243994338
# Test ROS RMSE for RF: 0.008229606705069045
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.272220107231281
# Test ROS RMSE for XGB: 0.00691185458843961
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.376983571333755
# Test ROS RMSE for LM: 0.007743592703033383
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.242068656667836
# Test ROS RMSE for RF: 0.0070341928324862526
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 166
# t: 2024-04-13 02:22:00
# Number of Training Observations: 55684
# Number of Training Locations: 88
# Number of Features: 16
# Time range Train: ('2024-04-13 02:22:00', '2024-05-11 02:17:00')
# ----------
# Number of Test Observations: 1053
# Number of Test Locations: 22
# Time range Test: ('2024-05-11 02:20:00', '2024-05-13 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.755627079842639
# Test ROS RMSE for XGB: 0.007976013368043483
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.464092950141327
# Test ROS RMSE for LM: 0.007550221669061905
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.127353550068101
# Test ROS RMSE for RF: 0.008199515502623178
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.816956365959869
# Test ROS RMSE for XGB: 0.008051861761926906
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.5248075448082705
# Test ROS RMSE for LM: 0.007628314183638301
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.138955060576434
# Test ROS RMSE for RF: 0.0082586528221174
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.879937421648943
# Test ROS RMSE for XGB: 0.00806530080361968
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.73772234815003
# Test ROS RMSE for LM: 0.00789053803943616
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.257847928267827
# Test ROS RMSE for RF: 0.008405590019614271
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.95406316728475
# Test ROS RMSE for XGB: 0.008066750104004674
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.011780362499191
# Test ROS RMSE for LM: 0.00820272340758995
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.379258043599804
# Test ROS RMSE for RF: 0.008575574285706097
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.124244763733202
# Test ROS RMSE for XGB: 0.008360527111831849
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.328126786487975
# Test ROS RMSE for LM: 0.008545175090407397
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.467373607815403
# Test ROS RMSE for RF: 0.008682039333322773
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.321109872209889
# Test ROS RMSE for XGB: 0.008583113173756454
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.661784243718436
# Test ROS RMSE for LM: 0.008901577753172891
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.459889992467241
# Test ROS RMSE for RF: 0.008712456057763551
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.526731290571116
# Test ROS RMSE for XGB: 0.00877436319452429
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.990326681254652
# Test ROS RMSE for LM: 0.009260708106772028
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.801780559678759
# Test ROS RMSE for RF: 0.009158428438344421
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.565748071768073
# Test ROS RMSE for XGB: 0.00886823584487746
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.3014207830178774
# Test ROS RMSE for LM: 0.009620837744728024
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.06456968170629
# Test ROS RMSE for RF: 0.00943697967217078
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.840381365920628
# Test ROS RMSE for XGB: 0.009182346202859442
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.5858011485179855
# Test ROS RMSE for LM: 0.009973515162216322
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.302123793918581
# Test ROS RMSE for RF: 0.00973900506772827
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.095262787829851
# Test ROS RMSE for XGB: 0.009484033175203903
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.8399964964837165
# Test ROS RMSE for LM: 0.010312227424026372
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.559370221163818
# Test ROS RMSE for RF: 0.010067121387290101
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.403774659715648
# Test ROS RMSE for XGB: 0.0098902355918937
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 7.066845767796013
# Test ROS RMSE for LM: 0.010641006200478203
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.910070091593623
# Test ROS RMSE for RF: 0.010577249245390554
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.848725401818647
# Test ROS RMSE for XGB: 0.008008757648545726
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.910350588430425
# Test ROS RMSE for LM: 0.008111502409960156
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.108666337653839
# Test ROS RMSE for RF: 0.008235202367988853

# %%
results_fm = []
results_ros = []
for l in loss_dict:
    for mod in loss_dict[l]["errs"]:
        errs = loss_dict[l]["errs"][mod]['rmse_test']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_fm.append(pd.DataFrame(temp))
        errs = loss_dict[l]["errs"][mod]['rmse_test_ROS']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test_ROS'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_ros.append(pd.DataFrame(temp))

# %%
results_fm = pd.concat(results_fm)
results_fm
# Out:
#          RMSE Loss Model                   t
# 0    3.857785  MSE   XGB 2023-05-17 02:22:00
# 1    3.301552  MSE   XGB 2023-05-19 02:22:00
# 2    2.768666  MSE   XGB 2023-05-21 02:22:00
# 3    3.432500  MSE   XGB 2023-05-23 02:22:00
# 4    4.353253  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  3.311077  ROS    RF 2024-04-05 02:22:00
# 163  3.499201  ROS    RF 2024-04-07 02:22:00
# 164  4.323424  ROS    RF 2024-04-09 02:22:00
# 165  4.242069  ROS    RF 2024-04-11 02:22:00
# 166  5.108666  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
results_ros = pd.concat(results_ros)
results_ros
# Out:
#          RMSE Loss Model                   t
# 0    0.006083  MSE   XGB 2023-05-17 02:22:00
# 1    0.005584  MSE   XGB 2023-05-19 02:22:00
# 2    0.005014  MSE   XGB 2023-05-21 02:22:00
# 3    0.008346  MSE   XGB 2023-05-23 02:22:00
# 4    0.007606  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  0.006433  ROS    RF 2024-04-05 02:22:00
# 163  0.005433  ROS    RF 2024-04-07 02:22:00
# 164  0.007845  ROS    RF 2024-04-09 02:22:00
# 165  0.007034  ROS    RF 2024-04-11 02:22:00
# 166  0.008235  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
# Write Dataframe
with open(osp.join("outputs", "results_fm.pkl"), 'wb') as handle:
    pickle.dump(results_fm, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(osp.join("outputs", "results_ros.pkl"), 'wb') as handle:
    pickle.dump(results_ros, handle, protocol=pickle.HIGHEST_PROTOCOL)
