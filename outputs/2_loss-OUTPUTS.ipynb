# %% [markdown]
# # Test Loss Functions on Multiple Models

# %%
import sys
sys.path.append('src')
import pandas as pd
import numpy as np
import xgboost as xg
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from utils import create_exp_function, loss_setup, initialize_models
import yaml
import pickle
import os.path as osp
from datetime import timedelta
import matplotlib.pyplot as plt
# Local modules
from data_funcs import train_test_split_spacetime
from fmda_models import LM, XGB, RF
from metrics import ros_0wind, ros_3wind, rmse
import reproducibility

# %% [markdown]
# ## Read Data

# %%
df = pd.read_pickle("data/raws_df.pkl")
df = df.dropna()
df.columns
# Out:
# Index(['Ew', 'Ed', 'temp', 'rh', 'rain', 'precip_accum', 'fm', 'wind', 'solar',
#        'time_raws', 'STID', 'lat', 'lon', 'elev', 'hour', 'doy', 'date'],
#       dtype='object')

# %%
df
# Out:
#                             Ew         Ed     temp    rh  rain  precip_accum  \
# 2023-05-17 03:09:00  13.147834  14.552503  284.817  48.0  0.00       470.408
# 2023-05-17 04:09:00  13.247513  14.652182  284.261  48.0  0.00       470.408
# 2023-05-17 05:09:00  12.876054  14.274707  284.261  46.0  0.00       470.408
# 2023-05-17 06:09:00  13.446692  14.851361  283.150  48.0  0.00       470.408
# 2023-05-17 07:09:00  14.000874  15.412836  283.150  51.0  0.00       470.408
# ...                        ...        ...      ...   ...   ...           ...
# 2024-05-14 19:17:00   5.988904   7.156126  293.706  20.0  0.00         6.096
# 2024-05-14 20:17:00   9.688784  11.031949  290.372  35.0  0.00         6.096
# 2024-05-14 21:17:00  11.794500  13.189754  289.261  45.0  5.08        11.176
# 2024-05-14 22:17:00   7.987530   9.267817  292.039  28.0  0.00        11.176
# 2024-05-14 23:17:00   7.970651   9.239580  290.928  27.0  0.00        11.176
#
#                       fm   wind  solar           time_raws   STID       lat  \
# 2023-05-17 03:09:00  7.5  1.790    1.0 2023-05-17 03:09:00  CPTC2  38.45944
# 2023-05-17 04:09:00  8.1  1.790    0.0 2023-05-17 04:09:00  CPTC2  38.45944
# 2023-05-17 05:09:00  8.6  1.790    0.0 2023-05-17 05:09:00  CPTC2  38.45944
# 2023-05-17 06:09:00  9.2  1.790    0.0 2023-05-17 06:09:00  CPTC2  38.45944
# 2023-05-17 07:09:00  9.6  1.790    0.0 2023-05-17 07:09:00  CPTC2  38.45944
# ...                  ...    ...    ...                 ...    ...       ...
# 2024-05-14 19:17:00  9.4  1.343  970.0 2024-05-14 19:17:00  TT815  37.52272
# 2024-05-14 20:17:00  7.3  0.448  426.0 2024-05-14 20:17:00  TT815  37.52272
# 2024-05-14 21:17:00  8.0  1.343  594.0 2024-05-14 21:17:00  TT815  37.52272
# 2024-05-14 22:17:00  8.0  1.790  742.0 2024-05-14 22:17:00  TT815  37.52272
# 2024-05-14 23:17:00  8.2  0.895  362.0 2024-05-14 23:17:00  TT815  37.52272
#
#                            lon  elev  hour  doy                date
# 2023-05-17 03:09:00 -109.04694  8088     3  137 2023-05-17 03:09:00
# 2023-05-17 04:09:00 -109.04694  8088     4  137 2023-05-17 04:09:00
# 2023-05-17 05:09:00 -109.04694  8088     5  137 2023-05-17 05:09:00
# 2023-05-17 06:09:00 -109.04694  8088     6  137 2023-05-17 06:09:00
# 2023-05-17 07:09:00 -109.04694  8088     7  137 2023-05-17 07:09:00
# ...                        ...   ...   ...  ...                 ...
# 2024-05-14 19:17:00 -108.48178  7576    19  135 2024-05-14 19:17:00
# 2024-05-14 20:17:00 -108.48178  7576    20  135 2024-05-14 20:17:00
# 2024-05-14 21:17:00 -108.48178  7576    21  135 2024-05-14 21:17:00
# 2024-05-14 22:17:00 -108.48178  7576    22  135 2024-05-14 22:17:00
# 2024-05-14 23:17:00 -108.48178  7576    23  135 2024-05-14 23:17:00
#
# [875127 rows x 17 columns]

# %% [markdown]
# ## Setup Models

# %%
with open('models/params.yaml', 'r') as file:
    params = yaml.safe_load(file)

params
# Out:
# {'xgb': {'max_depth': 4,
#   'eta': 0.1,
#   'min_child_weight': 1,
#   'subsample': 0.8,
#   'colsample_bytree': 0.9,
#   'scale_pos_weight': 1,
#   'n_estimators': 120,
#   'gamma': 0.1},
#  'rf': {'n_estimators': 50,
#   'criterion': 'squared_error',
#   'max_depth': 8,
#   'min_samples_split': 2,
#   'min_samples_leaf': 1,
#   'max_features': 0.8,
#   'bootstrap': True,
#   'max_samples': None,
#   'random_state': None,
#   'verbose': 0,
#   'warm_start': False},
#  'mlp': {'hidden_units': 10,
#   'activation': 'relu',
#   'optimizer': 'adam',
#   'epochs': 10,
#   'batch_size': 32,
#   'validation_split': 0.2,
#   'dropout': 0.2,
#   'learning_rate': 0.001},
#  'lm': {'fit_intercept': True}}

# %%
weight_grid=np.round(np.linspace(0.01, .25, 10), 4)
models, loss_dict = loss_setup(params=params, ws=weight_grid)
# loss_dict

# %% [markdown]
# ## Run Analysis

# %%
## COLUMNS SUBSET
cols = ["Ed", "rain", "wind", "solar", "hour", "doy", "lat", "lon", 'elev']
reproducibility.set_seed(123)
nreps = 5
# Out:
# resetting random seeds to 123

# %% [markdown]
# For each loss function and each model, we will collect 2 arrays of errors on the test set. One for the RMSE on the test fuel moisture observations, and another one on the RMSE for the same observations transformed to ROS.

# %%
t = df.index.min()
i = 0
tdelta = 2 # number of days to shift train/test period
for j in range(0, nreps):
    print(f"Replication iteration: {j}")
    while t <= (df.index.max() - timedelta(days = 30)):
        print("~"*50)
        print(f"Iteration: {i}")
        print(f"t: {t}")
        # Build train/test from 30 day period after t
        df_temp = df[
            (df.index >= t) & (df.index < (t + timedelta(days=30)))
        ]
        X_train, X_test, y_train, y_test = train_test_split_spacetime(
            df_temp, 
            test_days = 2,
            spatial_test_frac = 0.2,
            verbose = True
        )
        X_train = X_train[cols]
        X_test = X_test[cols]
        # Run models
        # Reinitialize models dictionary to prevent multiple fitting iterations
        if True:
            models = initialize_models(params)
        for l in loss_dict:
            print("~"*50)
            print(f"Running models for loss func: {l}")
            if loss_dict[l]['w_func'] is not None:
                weights = loss_dict[l]['w_func'](y_train)
            else:
                weights = None
    
            for mod in models:
                print(f"Fitting {mod}")
                models[mod].fit(X_train, y_train, weights)
                preds = models[mod].predict(X_test)
                loss_dict[l][f"errs"][mod]["t"].append(t)
                loss_dict[l][f"errs"][mod]["rmse_test"].append(rmse(preds, y_test))
                loss_dict[l][f"errs"][mod]["rmse_test_ROS"].append(rmse(ros_3wind(preds), ros_3wind(y_test)))
                print(f"Test RMSE for {mod}: {rmse(preds, y_test)}")
                print(f"Test ROS RMSE for {mod}: {rmse(ros_3wind(preds), ros_3wind(y_test))}")
    
        # # Iterate test period by 2 so no overlap
        i+= 1 # iteration counter
        t = t + timedelta(days=tdelta)
# Out:
# Replication iteration: 0
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 0
# t: 2023-05-17 02:22:00
# Number of Training Observations: 52395
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-17 02:22:00', '2023-06-14 02:18:00')
# ----------
# Number of Test Observations: 1058
# Number of Test Locations: 22
# Time range Test: ('2023-06-14 02:20:00', '2023-06-16 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.506911518973545
# Test ROS RMSE for XGB: 0.0052416189061397144
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.7730695779094314
# Test ROS RMSE for LM: 0.005860908694495601
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5743642082850653
# Test ROS RMSE for RF: 0.0052648577336511715
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.546552437032468
# Test ROS RMSE for XGB: 0.0052968799607409625
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.7569040088723873
# Test ROS RMSE for LM: 0.005805774774292158
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5623354339923585
# Test ROS RMSE for RF: 0.005263534839910401
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5638463111118543
# Test ROS RMSE for XGB: 0.005296303189075096
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.748521475548426
# Test ROS RMSE for LM: 0.005714553162999185
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.564444294813387
# Test ROS RMSE for RF: 0.0052620998065401915
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5548455809135873
# Test ROS RMSE for XGB: 0.00532319670608563
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.78755413464087
# Test ROS RMSE for LM: 0.005709704338849611
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6109947961209334
# Test ROS RMSE for RF: 0.005343828459361476
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.624700034741943
# Test ROS RMSE for XGB: 0.005438569399780256
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.8715780158278146
# Test ROS RMSE for LM: 0.005784318156238975
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6020783670934815
# Test ROS RMSE for RF: 0.005334937904164594
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7529097607314363
# Test ROS RMSE for XGB: 0.0055842525528353405
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.99635901617744
# Test ROS RMSE for LM: 0.005924153688456271
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.659737632092043
# Test ROS RMSE for RF: 0.005413972115082281
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.783188607824202
# Test ROS RMSE for XGB: 0.0056205006343058635
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.153955612176631
# Test ROS RMSE for LM: 0.006113051573245641
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7236817295268034
# Test ROS RMSE for RF: 0.005506924433387195
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.884291343646841
# Test ROS RMSE for XGB: 0.00575007506112052
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.335535761384171
# Test ROS RMSE for LM: 0.006335245444920811
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.82461198763971
# Test ROS RMSE for RF: 0.005651718528641623
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.945098157271184
# Test ROS RMSE for XGB: 0.00582241059052985
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.529578559489414
# Test ROS RMSE for LM: 0.006572684255486106
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.929895376561072
# Test ROS RMSE for RF: 0.005779541789550822
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.038732078224704
# Test ROS RMSE for XGB: 0.005957209167000277
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.725455556291897
# Test ROS RMSE for LM: 0.006817054424052615
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.029972758334713
# Test ROS RMSE for RF: 0.005906197971758961
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.180224728368293
# Test ROS RMSE for XGB: 0.006144019893081938
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.917153463969199
# Test ROS RMSE for LM: 0.007064469038657044
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.153630364259542
# Test ROS RMSE for RF: 0.006064860359655271
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.5420878130884703
# Test ROS RMSE for XGB: 0.005317338577892641
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.764792178529381
# Test ROS RMSE for LM: 0.005712909359800947
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5107984132103316
# Test ROS RMSE for RF: 0.00521762465010709
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 1
# t: 2023-05-19 02:22:00
# Number of Training Observations: 53553
# Number of Training Locations: 85
# Number of Features: 16
# Time range Train: ('2023-05-19 02:22:00', '2023-06-16 02:18:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-16 02:23:00', '2023-06-18 02:16:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.623817364696757
# Test ROS RMSE for XGB: 0.00604670310015182
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.9017092104933524
# Test ROS RMSE for LM: 0.006494136165635164
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.450274222154067
# Test ROS RMSE for RF: 0.005683333759218313
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7063937487191705
# Test ROS RMSE for XGB: 0.006187050461512432
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.9374477055952846
# Test ROS RMSE for LM: 0.006509393599341295
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.5192845103834016
# Test ROS RMSE for RF: 0.005799800105639067
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.76836861616272
# Test ROS RMSE for XGB: 0.00628013395590039
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.068396490635361
# Test ROS RMSE for LM: 0.0066385841317894816
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.6491255497191504
# Test ROS RMSE for RF: 0.005967251498649198
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.784315439636017
# Test ROS RMSE for XGB: 0.006169468419408832
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.251838281341992
# Test ROS RMSE for LM: 0.006891056457169835
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.802535242643406
# Test ROS RMSE for RF: 0.006193401722903013
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9778984610736767
# Test ROS RMSE for XGB: 0.006438571992888902
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.487791391025275
# Test ROS RMSE for LM: 0.0072476044313933815
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.981402974798707
# Test ROS RMSE for RF: 0.0064389975614922235
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.17180009548531
# Test ROS RMSE for XGB: 0.006801638087743387
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.768270703808626
# Test ROS RMSE for LM: 0.007671402362931643
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.1714861035061075
# Test ROS RMSE for RF: 0.006741912230662852
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.318409053886162
# Test ROS RMSE for XGB: 0.006989935780512111
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.079058878730753
# Test ROS RMSE for LM: 0.008118095587006649
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.373111014516698
# Test ROS RMSE for RF: 0.006999393015631105
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.502639723751884
# Test ROS RMSE for XGB: 0.007200761924412469
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.406724934983414
# Test ROS RMSE for LM: 0.008558636079158952
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.5777083533042076
# Test ROS RMSE for RF: 0.007277093632452356
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.6640588386662944
# Test ROS RMSE for XGB: 0.007397113956363091
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.734949179101977
# Test ROS RMSE for LM: 0.008978022804581265
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.809065474337112
# Test ROS RMSE for RF: 0.007653943321604616
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.917843382478374
# Test ROS RMSE for XGB: 0.007779473077374716
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.05051056172442
# Test ROS RMSE for LM: 0.009364486034162602
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.001073693967329
# Test ROS RMSE for RF: 0.007896116414022923
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.138435943986721
# Test ROS RMSE for XGB: 0.008122412861248356
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.3478868894911376
# Test ROS RMSE for LM: 0.009719607894802449
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.2678654910365665
# Test ROS RMSE for RF: 0.008324796915221623
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.7639845905178397
# Test ROS RMSE for XGB: 0.00624716336122452
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.159689109473367
# Test ROS RMSE for LM: 0.006774730578921728
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.7228678672749456
# Test ROS RMSE for RF: 0.006164346395852475
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 2
# t: 2023-05-21 02:22:00
# Number of Training Observations: 53663
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-21 02:22:00', '2023-06-18 02:18:00')
# ----------
# Number of Test Observations: 1054
# Number of Test Locations: 22
# Time range Test: ('2023-06-18 02:20:00', '2023-06-20 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7026228279060196
# Test ROS RMSE for XGB: 0.004678036940001713
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9738185686070726
# Test ROS RMSE for LM: 0.005030817115496773
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7928472086118235
# Test ROS RMSE for RF: 0.004347193276801076
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6868606074096046
# Test ROS RMSE for XGB: 0.004513858549819344
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.95751549318497
# Test ROS RMSE for LM: 0.005014151931333713
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.782682964491235
# Test ROS RMSE for RF: 0.004342390165349905
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6326642638789295
# Test ROS RMSE for XGB: 0.0044588694639236875
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9436465860065644
# Test ROS RMSE for LM: 0.005009564993185621
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7529871825613452
# Test ROS RMSE for RF: 0.004310569731220576
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.644610962493239
# Test ROS RMSE for XGB: 0.004392525311777497
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9636138781772243
# Test ROS RMSE for LM: 0.005027081780803168
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7503835958032816
# Test ROS RMSE for RF: 0.004332124078602087
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.633091960511356
# Test ROS RMSE for XGB: 0.004314511700386228
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0114861719211485
# Test ROS RMSE for LM: 0.00505260442369525
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.727533893658698
# Test ROS RMSE for RF: 0.0042677501496041015
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.630022827582259
# Test ROS RMSE for XGB: 0.0042860953430267305
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.0842019879401077
# Test ROS RMSE for LM: 0.005087073161754463
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.767184094804835
# Test ROS RMSE for RF: 0.004322641181711354
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6472794131774124
# Test ROS RMSE for XGB: 0.004265915735433784
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1781703723803183
# Test ROS RMSE for LM: 0.0051386267618286265
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.787978263565179
# Test ROS RMSE for RF: 0.004308757851455706
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.714282799316395
# Test ROS RMSE for XGB: 0.0043132154869961956
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.289327011584202
# Test ROS RMSE for LM: 0.005213296602001433
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8517148268295487
# Test ROS RMSE for RF: 0.0044613063558262105
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.749340280710871
# Test ROS RMSE for XGB: 0.004334973821782495
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.411294741210688
# Test ROS RMSE for LM: 0.0053104851493253015
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.930553190795873
# Test ROS RMSE for RF: 0.004577743289110057
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7784229377571754
# Test ROS RMSE for XGB: 0.00435785009472893
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.5374251438906423
# Test ROS RMSE for LM: 0.005426583140859304
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.0128046636192845
# Test ROS RMSE for RF: 0.004661779545170641
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.8779890558924723
# Test ROS RMSE for XGB: 0.004459334407425889
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.6634879570456484
# Test ROS RMSE for LM: 0.0055565260582461605
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.06449014126902
# Test ROS RMSE for RF: 0.004696562892903546
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.669854292277741
# Test ROS RMSE for XGB: 0.004457569448098384
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9444870543097448
# Test ROS RMSE for LM: 0.004963656473002541
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.7424848264949593
# Test ROS RMSE for RF: 0.004293071176414704
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 3
# t: 2023-05-23 02:22:00
# Number of Training Observations: 53473
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-23 02:22:00', '2023-06-20 02:18:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-20 02:20:00', '2023-06-22 02:20:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.8401141277050743
# Test ROS RMSE for XGB: 0.00609934895700639
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.1976055635020146
# Test ROS RMSE for LM: 0.006351516829370201
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.910675106094909
# Test ROS RMSE for RF: 0.005968578980690883
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7579800271721946
# Test ROS RMSE for XGB: 0.005945779508335764
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 3.121517989969556
# Test ROS RMSE for LM: 0.006209192841708677
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.8657945813523655
# Test ROS RMSE for RF: 0.005916377332143881
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.783824096834971
# Test ROS RMSE for XGB: 0.00611353198592892
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.9475874553206447
# Test ROS RMSE for LM: 0.0058930884676659445
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.749842927789842
# Test ROS RMSE for RF: 0.005754738592657071
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.6869149842680806
# Test ROS RMSE for XGB: 0.005947411975858631
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.8124644491275435
# Test ROS RMSE for LM: 0.005647327720081168
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.647206429726106
# Test ROS RMSE for RF: 0.005609220277220387
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.7146793387493084
# Test ROS RMSE for XGB: 0.005975821063659798
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.715621020942529
# Test ROS RMSE for LM: 0.0054559745421761344
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.5641444385335515
# Test ROS RMSE for RF: 0.005551838652650722
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.469219676065452
# Test ROS RMSE for XGB: 0.0054834462377681015
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.660866608895886
# Test ROS RMSE for LM: 0.0053171499650854345
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4919601779189735
# Test ROS RMSE for RF: 0.005285794495162768
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5489657735184723
# Test ROS RMSE for XGB: 0.005587199707754129
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.6494178696414674
# Test ROS RMSE for LM: 0.005226467208873614
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4782620586610706
# Test ROS RMSE for RF: 0.005316903640838665
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5505045313966863
# Test ROS RMSE for XGB: 0.005714862050726974
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.677727842612261
# Test ROS RMSE for LM: 0.005181956563993745
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.4957950672329576
# Test ROS RMSE for RF: 0.005445281117851522
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.4683294210716125
# Test ROS RMSE for XGB: 0.00540804467910392
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.7380202709842694
# Test ROS RMSE for LM: 0.0051750028205397
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.494152781524208
# Test ROS RMSE for RF: 0.0054250048940772694
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.534420164295372
# Test ROS RMSE for XGB: 0.005532718800911242
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.820012924242999
# Test ROS RMSE for LM: 0.005197399491141529
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.5138450692878855
# Test ROS RMSE for RF: 0.005359759325064523
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5574426310019494
# Test ROS RMSE for XGB: 0.005262586439069928
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.914926722724285
# Test ROS RMSE for LM: 0.005242029686582799
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.560487351847783
# Test ROS RMSE for RF: 0.00526303912013685
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 2.5340848763220314
# Test ROS RMSE for XGB: 0.005440997441452444
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 2.867395969647049
# Test ROS RMSE for LM: 0.005740617431992254
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 2.6731787675802123
# Test ROS RMSE for RF: 0.0056836017641111085
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 4
# t: 2023-05-25 02:22:00
# Number of Training Observations: 53730
# Number of Training Locations: 84
# Number of Features: 16
# Time range Train: ('2023-05-25 02:22:00', '2023-06-22 02:18:00')
# ----------
# Number of Test Observations: 1008
# Number of Test Locations: 21
# Time range Test: ('2023-06-22 02:22:00', '2023-06-24 02:16:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 3.9190408051523455
# Test ROS RMSE for XGB: 0.006976532809032094
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.055095070842483
# Test ROS RMSE for LM: 0.007923766376266732
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.4901877358196973
# Test ROS RMSE for RF: 0.006110294079981637
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.062133369062372
# Test ROS RMSE for XGB: 0.007373045828905063
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.049071405268264
# Test ROS RMSE for LM: 0.007883273294592272
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 3.47488667444889
# Test ROS RMSE for RF: 0.006126155560447006
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.130978462064189
# Test ROS RMSE for XGB: 0.0075338097959750765
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.056382661345628
# Test ROS RMSE for LM: 0.007781567517484657
# Fitting RF
# ...
# Predicting with RF
# Test RMSE for RF: 5.304425059479477
# Test ROS RMSE for RF: 0.008896962088424847
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.806639939497321
# Test ROS RMSE for XGB: 0.009433387017208247
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.136427385187881
# Test ROS RMSE for LM: 0.010008798469410909
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.5911895082803404
# Test ROS RMSE for RF: 0.009203273430542776
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.029657002122719
# Test ROS RMSE for XGB: 0.009668856423238264
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.439059319762096
# Test ROS RMSE for LM: 0.01027607641987311
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.748855180235189
# Test ROS RMSE for RF: 0.009375707650558536
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.292542497665271
# Test ROS RMSE for XGB: 0.009907289336070017
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.7110709481454744
# Test ROS RMSE for LM: 0.010532325009250956
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.9571829062323305
# Test ROS RMSE for RF: 0.009617647819298985
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.5824778011757274
# Test ROS RMSE for XGB: 0.010305128553217571
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.954427515906492
# Test ROS RMSE for LM: 0.010777889855067712
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.304870738199913
# Test ROS RMSE for RF: 0.009989906977339124
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 4.769812072324848
# Test ROS RMSE for XGB: 0.008355066972674264
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.80153470433416
# Test ROS RMSE for LM: 0.00883311421065439
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.516944635183248
# Test ROS RMSE for RF: 0.008086184988805182
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration: 166
# t: 2024-04-13 02:22:00
# Number of Training Observations: 55974
# Number of Training Locations: 88
# Number of Features: 16
# Time range Train: ('2024-04-13 02:22:00', '2024-05-11 02:16:00')
# ----------
# Number of Test Observations: 1052
# Number of Test Locations: 22
# Time range Test: ('2024-05-11 02:24:00', '2024-05-13 02:17:00')
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: MSE
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.007591133820083
# Test ROS RMSE for XGB: 0.008115330367834498
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.561006299310571
# Test ROS RMSE for LM: 0.007547787162771507
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.752661124554486
# Test ROS RMSE for RF: 0.007769793118635075
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.01
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.246682152160673
# Test ROS RMSE for XGB: 0.008587485476499445
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.60332199656345
# Test ROS RMSE for LM: 0.007612595882690982
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.853207514464276
# Test ROS RMSE for RF: 0.007882874376276773
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0367
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.262904989571931
# Test ROS RMSE for XGB: 0.008420454978441128
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.788562563588263
# Test ROS RMSE for LM: 0.007867185099263523
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 4.957970479306968
# Test ROS RMSE for RF: 0.008015185948387333
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.0633
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.364584336855692
# Test ROS RMSE for XGB: 0.008528983580790479
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.063006601508171
# Test ROS RMSE for LM: 0.00820339096365644
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.153035725351714
# Test ROS RMSE for RF: 0.008238558282453096
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.09
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.321230162086469
# Test ROS RMSE for XGB: 0.008425953231081584
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.401170548305264
# Test ROS RMSE for LM: 0.008579086597825669
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.3234871936125465
# Test ROS RMSE for RF: 0.008451161160240557
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1167
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.394698089891346
# Test ROS RMSE for XGB: 0.008552526396493714
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 5.77023454155112
# Test ROS RMSE for LM: 0.008971894483322853
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.524063658057433
# Test ROS RMSE for RF: 0.008728242942764157
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1433
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.768048776395462
# Test ROS RMSE for XGB: 0.00897268842791531
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.140386244670648
# Test ROS RMSE for LM: 0.00936625223496805
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.7866244185925195
# Test ROS RMSE for RF: 0.0090663483522117
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.17
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.937136327541039
# Test ROS RMSE for XGB: 0.009243413339123234
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.494208228711593
# Test ROS RMSE for LM: 0.009761031865368596
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.324185472422917
# Test ROS RMSE for RF: 0.009773722176746213
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.1967
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.976944288743212
# Test ROS RMSE for XGB: 0.009217611433043543
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 6.818955228338983
# Test ROS RMSE for LM: 0.010148202662972124
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.523929674521357
# Test ROS RMSE for RF: 0.010022080772229845
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.2233
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.301703621865117
# Test ROS RMSE for XGB: 0.009616047467024259
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 7.109449321526429
# Test ROS RMSE for LM: 0.010525003758641703
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 6.849489846140389
# Test ROS RMSE for RF: 0.010409310325780201
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: exp_0.25
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 6.684535792727414
# Test ROS RMSE for XGB: 0.010167306059222928
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 7.368417087480125
# Test ROS RMSE for LM: 0.010884274358081213
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 7.136081526187947
# Test ROS RMSE for RF: 0.010815593708756649
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running models for loss func: ROS
# Fitting XGB
# Training XGB with params: {'max_depth': 4, 'eta': 0.1, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.9, 'scale_pos_weight': 1, 'n_estimators': 120, 'gamma': 0.1}
# Predicting with XGB
# Test RMSE for XGB: 5.251493017386207
# Test ROS RMSE for XGB: 0.008410493905266402
# Fitting LM
# Training LM with params: {'fit_intercept': True}
# Predicting with LM
# Test RMSE for LM: 4.976187323075366
# Test ROS RMSE for LM: 0.008115794765045188
# Fitting RF
# Training RF with params: {'n_estimators': 50, 'criterion': 'squared_error', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.8, 'bootstrap': True, 'max_samples': None, 'random_state': None, 'verbose': 0, 'warm_start': False}
# Predicting with RF
# Test RMSE for RF: 5.007364856491107
# Test ROS RMSE for RF: 0.008089783978388798
# Replication iteration: 1
# Replication iteration: 2
# Replication iteration: 3
# Replication iteration: 4

# %%
results_fm = []
results_ros = []
for l in loss_dict:
    for mod in loss_dict[l]["errs"]:
        errs = loss_dict[l]["errs"][mod]['rmse_test']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_fm.append(pd.DataFrame(temp))
        errs = loss_dict[l]["errs"][mod]['rmse_test_ROS']
        temp = {
            'RMSE': loss_dict[l]["errs"][mod]['rmse_test_ROS'],
            'Loss': [l] * len(errs),
            'Model': [mod] * len(errs),
            't': loss_dict[l]["errs"][mod]['t']
        }
        results_ros.append(pd.DataFrame(temp))

# %%
results_fm = pd.concat(results_fm)
results_fm
# Out:
#          RMSE Loss Model                   t
# 0    3.506912  MSE   XGB 2023-05-17 02:22:00
# 1    3.623817  MSE   XGB 2023-05-19 02:22:00
# 2    2.702623  MSE   XGB 2023-05-21 02:22:00
# 3    2.840114  MSE   XGB 2023-05-23 02:22:00
# 4    3.919041  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  4.311108  ROS    RF 2024-04-05 02:22:00
# 163  3.800491  ROS    RF 2024-04-07 02:22:00
# 164  3.653255  ROS    RF 2024-04-09 02:22:00
# 165  4.516945  ROS    RF 2024-04-11 02:22:00
# 166  5.007365  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
results_ros = pd.concat(results_ros)
results_ros
# Out:
#          RMSE Loss Model                   t
# 0    0.005242  MSE   XGB 2023-05-17 02:22:00
# 1    0.006047  MSE   XGB 2023-05-19 02:22:00
# 2    0.004678  MSE   XGB 2023-05-21 02:22:00
# 3    0.006099  MSE   XGB 2023-05-23 02:22:00
# 4    0.006977  MSE   XGB 2023-05-25 02:22:00
# ..        ...  ...   ...                 ...
# 162  0.007323  ROS    RF 2024-04-05 02:22:00
# 163  0.005849  ROS    RF 2024-04-07 02:22:00
# 164  0.006606  ROS    RF 2024-04-09 02:22:00
# 165  0.008086  ROS    RF 2024-04-11 02:22:00
# 166  0.008090  ROS    RF 2024-04-13 02:22:00
#
# [6012 rows x 4 columns]

# %%
# Write Dataframe
with open(osp.join("outputs", "results_fm.pkl"), 'wb') as handle:
    pickle.dump(results_fm, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(osp.join("outputs", "results_ros.pkl"), 'wb') as handle:
    pickle.dump(results_ros, handle, protocol=pickle.HIGHEST_PROTOCOL)
